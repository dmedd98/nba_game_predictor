# %%
import pandas as pd
import pickle
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
pd.set_option('display.max_columns', None)

# %%
with open('data/pickles/model_df21.p', 'rb') as readfile: 
    model_df21 = pickle.load(readfile)

# %%
model_df21.corr()['PLUS_MINUS'].sort_values(ascending=False)[:20]
# Out:
# PLUS_MINUS            1.000000
# NET_RATING            0.995623
# PIE                   0.946969
# WIN                   0.800999
# OFF_RATING            0.663361
# TS_PCT                0.609452
# PTS                   0.607946
# EFG_PCT_y             0.601672
# NET_RATING LAST 10    0.246151
# PLUS_MINUS LAST 10    0.245054
# PIE LAST 10           0.237332
# OFF_RATING LAST 10    0.230018
# OFF_RATING Season     0.223924
# AST_TOV               0.219942
# TS_PCT Season         0.218171
# PIE Season            0.215202
# PLUS_MINUS Season     0.213961
# NET_RATING Season     0.213185
# TS_PCT LAST 10        0.208713
# EFG_PCT_y Season      0.202536
# Name: PLUS_MINUS, dtype: float64

# %%
with open('data/pickles/splitdf21.p', 'rb') as readfile: 
    splitdf21 = pickle.load(readfile)

# %%
win = splitdf21.corr()['PLUS_MINUS'].sort_values(ascending=False)[:20]
loss = splitdf21.corr()['PLUS_MINUS'].sort_values(ascending=True)[:20]

# %%
win
# Out:
# PLUS_MINUS      1.000000
# NET_RATING      0.995623
# E_NET_RATING    0.979415
# PIE             0.946969
# OFF_RATING      0.663361
# E_OFF_RATING    0.655938
# TS_PCT          0.609452
# PTS             0.607946
# EFG_PCT_y       0.601672
# FG_PCT          0.567317
# FGM             0.550418
# REB_PCT         0.506975
# FG3_PCT         0.489403
# DREB            0.467267
# AST             0.403208
# FG3M            0.403161
# AST_RATIO       0.396933
# REB             0.382036
# AST_TOV         0.219942
# DREB_PCT        0.175013
# Name: PLUS_MINUS, dtype: float64

# %%
round(splitdf21.corr()['PLUS_MINUS'].sort_values(ascending=True)[:20], 4)
# Out:
# DEF_RATING     -0.6635
# E_DEF_RATING   -0.6561
# OPP_EFG_PCT    -0.6018
# OPP_OREB_PCT   -0.1751
# E_USG_PCT      -0.1488
# TOV            -0.1004
# E_TM_TOV_PCT   -0.0813
# TM_TOV_PCT_y   -0.0812
# FTA_RATE       -0.0280
# TEAM_ID        -0.0261
# FTA            -0.0194
# OREB           -0.0136
# PACE           -0.0000
# PACE_PER40     -0.0000
# E_PACE          0.0000
# MIN_x           0.0003
# POSS            0.0095
# OPP_FTA_RATE    0.0278
# FGA             0.0439
# FTM             0.0459
# Name: PLUS_MINUS, dtype: float64

# %%
sns.heatmap(splitdf21.corr().loc[['PLUS_MINUS'],:])
# Out:
# <AxesSubplot:>

# %%
sns.heatmap()
# Out:
# <AxesSubplot:>

# %%
teams = [
    [1610612737, 'ATL', 'Hawks', 1949, 'Atlanta', 'Atlanta Hawks', 'Atlanta'],
    [1610612738, 'BOS', 'Celtics', 1946, 'Boston', 'Boston Celtics', 'Massachusetts'],
    [1610612739, 'CLE', 'Cavaliers', 1970, 'Cleveland', 'Cleveland Cavaliers', 'Ohio'],
    [1610612740, 'NOP', 'Pelicans', 2002, 'New Orleans', 'New Orleans Pelicans', 'Louisiana'],
    [1610612741, 'CHI', 'Bulls', 1966, 'Chicago', 'Chicago Bulls', 'Illinois'],
    [1610612742, 'DAL', 'Mavericks', 1980, 'Dallas', 'Dallas Mavericks', 'Texas'],
    [1610612743, 'DEN', 'Nuggets', 1976, 'Denver', 'Denver Nuggets', 'Colorado'],
    [1610612744, 'GSW', 'Warriors', 1946, 'Golden State', 'Golden State Warriors', 'California'],
    [1610612745, 'HOU', 'Rockets', 1967, 'Houston', 'Houston Rockets', 'Texas'],
    [1610612746, 'LAC', 'Clippers', 1970, 'Los Angeles', 'Los Angeles Clippers', 'California'],
    [1610612747, 'LAL', 'Lakers', 1948, 'Los Angeles', 'Los Angeles Lakers', 'California'],
    [1610612748, 'MIA', 'Heat', 1988, 'Miami', 'Miami Heat', 'Florida'],
    [1610612749, 'MIL', 'Bucks', 1968, 'Milwaukee', 'Milwaukee Bucks', 'Wisconsin'],
    [1610612750, 'MIN', 'Timberwolves', 1989, 'Minnesota', 'Minnesota Timberwolves', 'Minnesota'],
    [1610612751, 'BKN', 'Nets', 1976, 'Brooklyn', 'Brooklyn Nets', 'New York'],
   [1610612752, 'NYK', 'Knicks', 1946, 'New York', 'New York Knicks', 'New York'],
    [1610612753, 'ORL', 'Magic', 1989, 'Orlando', 'Orlando Magic', 'Florida'],
   [1610612754, 'IND', 'Pacers', 1976, 'Indiana', 'Indiana Pacers', 'Indiana'],
    [1610612755, 'PHI', '76ers', 1949, 'Philadelphia', 'Philadelphia 76ers', 'Pennsylvania'],
      [1610612756, 'PHX', 'Suns', 1968, 'Phoenix', 'Phoenix Suns', 'Arizona'],
     [1610612757, 'POR', 'Trail Blazers', 1970, 'Portland', 'Portland Trail Blazers', 'Oregon'],
    [1610612758, 'SAC', 'Kings', 1948, 'Sacramento', 'Sacramento Kings', 'California'],
    [1610612759, 'SAS', 'Spurs', 1976, 'San Antonio', 'San Antonio Spurs', 'Texas'],
    [1610612760, 'OKC', 'Thunder', 1967, 'Oklahoma City', 'Oklahoma City Thunder', 'Oklahoma'],
    [1610612761, 'TOR', 'Raptors', 1995, 'Toronto', 'Toronto Raptors', 'Ontario'],
    [1610612762, 'UTA', 'Jazz', 1974, 'Utah', 'Utah Jazz', 'Utah'],
    [1610612763, 'MEM', 'Grizzlies', 1995, 'Memphis', 'Memphis Grizzlies', 'Tennessee'],
  [1610612764, 'WAS', 'Wizards', 1961, 'Washington', 'Washington Wizards', 'District of Columbia'],
    [1610612765, 'DET', 'Pistons', 1948, 'Detroit', 'Detroit Pistons', 'Michigan'],
    [1610612766, 'CHA', 'Hornets', 1988, 'Charlotte', 'Charlotte Hornets', 'North Carolina']
]

# %%
from nba_api.stats.endpoints import leaguedashteamstats
teamstats21 = leaguedashteamstats.LeagueDashTeamStats(season= '2020-21', measure_type_detailed_defense='Four Factors')
teamstats20 = leaguedashteamstats.LeagueDashTeamStats(season= '2019-20', measure_type_detailed_defense='Four Factors')
teamstats19 = leaguedashteamstats.LeagueDashTeamStats(season= '2018-19', measure_type_detailed_defense='Four Factors')
teamstats18 = leaguedashteamstats.LeagueDashTeamStats(season= '2017-18', measure_type_detailed_defense='Four Factors')
teamstats17 = leaguedashteamstats.LeagueDashTeamStats(season= '2016-17', measure_type_detailed_defense='Four Factors')
teamstats16 = leaguedashteamstats.LeagueDashTeamStats(season= '2015-16', measure_type_detailed_defense='Four Factors')

fourfactors21 = teamstats21.get_data_frames()[0]
fourfactors20 = teamstats20.get_data_frames()[0]
fourfactors19 = teamstats19.get_data_frames()[0]
fourfactors18 = teamstats18.get_data_frames()[0]
fourfactors17 = teamstats17.get_data_frames()[0]
fourfactors16 = teamstats16.get_data_frames()[0]

# %%
from nba_api.stats.endpoints import leaguedashteamstats
advancedstats21 = leaguedashteamstats.LeagueDashTeamStats(season= '2020-21', measure_type_detailed_defense='Advanced')
advanced21 = advancedstats21.get_data_frames()[0]
advancedstats20 = leaguedashteamstats.LeagueDashTeamStats(season= '2019-20', measure_type_detailed_defense='Advanced')
advanced20 = advancedstats20.get_data_frames()[0]
advancedstats19 = leaguedashteamstats.LeagueDashTeamStats(season= '2018-19', measure_type_detailed_defense='Advanced')
advanced19 = advancedstats19.get_data_frames()[0]
advancedstats18 = leaguedashteamstats.LeagueDashTeamStats(season= '2017-18', measure_type_detailed_defense='Advanced')
advanced18 = advancedstats18.get_data_frames()[0]
advancedstats17 = leaguedashteamstats.LeagueDashTeamStats(season= '2016-17', measure_type_detailed_defense='Advanced')
advanced17 = advancedstats17.get_data_frames()[0]
advancedstats16 = leaguedashteamstats.LeagueDashTeamStats(season= '2015-16', measure_type_detailed_defense='Advanced')
advanced16 = advancedstats16.get_data_frames()[0]

# %%
advanced21.corr()['W'].sort_values()
# Out:
# L                 -1.000000
# W_RANK            -0.991013
# W_PCT_RANK        -0.991013
# L_RANK            -0.991013
# NET_RATING_RANK   -0.949733
# PIE_RANK          -0.936434
# TS_PCT_RANK       -0.846467
# OFF_RATING_RANK   -0.795226
# EFG_PCT_RANK      -0.789749
# DEF_RATING_RANK   -0.654017
# DEF_RATING        -0.596260
# E_DEF_RATING      -0.594790
# REB_PCT_RANK      -0.593779
# AST_TO_RANK       -0.453353
# DREB_PCT_RANK     -0.409934
# TM_TOV_PCT        -0.339042
# TM_TOV_PCT_RANK   -0.307451
# AST_RATIO_RANK    -0.301974
# E_PACE            -0.273732
# PACE              -0.230987
# PACE_PER40        -0.230865
# POSS              -0.195996
# OREB_PCT_RANK     -0.185018
# AST_PCT           -0.153620
# MIN_RANK          -0.106556
# TEAM_ID           -0.071191
# MIN                0.134535
# AST_PCT_RANK       0.157637
# OREB_PCT           0.167881
# PACE_RANK          0.266379
# AST_RATIO          0.266567
# DREB_PCT           0.379263
# AST_TO             0.437631
# ...

# %%
from nba_api.stats.endpoints import leaguedashlineups

lineup = leaguedashlineups.LeagueDashLineups(season='2020-21')
lineup.get_data_frames()[0]
# Out:
#      GROUP_SET                                   GROUP_ID  \
# 0      Lineups    -101108-203109-1626164-1628969-1629028-
# 1      Lineups      -201980-202699-203552-203954-1627732-
# 2      Lineups    -202339-203500-1627742-1628366-1629627-
# 3      Lineups     -201144-202711-203497-1626220-1628378-
# 4      Lineups      -203457-203493-203901-203944-1629628-
# ...        ...                                        ...
# 1995   Lineups  -1627774-1627823-1629162-1629669-1629675-
# 1996   Lineups  -1626157-1627823-1629006-1629669-1629675-
# 1997   Lineups     -201152-202696-203107-1629632-1630172-
# 1998   Lineups    -201609-203473-1629134-1629622-1629644-
# 1999   Lineups   -202339-1628404-1628411-1629637-1630184-
#
#                                              GROUP_NAME     TEAM_ID  \
# 0     C. Paul - J. Crowder - D. Booker - M. Bridges ...  1610612756
# 1     D. Green - T. Harris - S. Curry - J. Embiid - ...  1610612755
# ...

# %%
from nba_api.stats.endpoints import teamdashlineups

lineup = teamdashlineups.TeamDashLineups(team_id= '1610612747', season='2020-21')

# %%
lineup.get_data_frames()[1]
# Out:
#     GROUP_SET                                GROUP_ID  \
# 0     Lineups      -2544-201188-203076-203471-203484-
# 1     Lineups   -201188-202693-203471-203484-1628398-
# 2     Lineups     -2544-201188-203471-203484-1628398-
# 3     Lineups   -202693-203083-203471-203484-1628398-
# 4     Lineups    -2544-202083-202693-1626149-1628398-
# ..        ...                                     ...
# 245   Lineups    -203076-203083-203463-203471-203484-
# 246   Lineups  -2544-1626149-1626188-1627936-1629659-
# 247   Lineups    -201188-202693-203463-203471-203484-
# 248   Lineups   -201188-202693-203471-203484-1629659-
# 249   Lineups   -201188-202083-203076-203484-1628398-
#
#                                             GROUP_NAME  GP   W  L  W_PCT  \
# 0    L. James - M. Gasol - A. Davis - D. Schroder -...  21  15  6  0.714
# 1    M. Gasol - M. Morris - D. Schroder - K. Caldwe...   7   5  2  0.714
# 2    L. James - M. Gasol - D. Schroder - K. Caldwel...   6   4  2  0.667
# ...

# %%
from nba_api.stats.endpoints import gamerotation

gr = gamerotation.GameRotation(game_id = '0022000001')

# %%
gr.get_data_frames()[0]
# Out:
#        GAME_ID     TEAM_ID     TEAM_CITY TEAM_NAME  PERSON_ID PLAYER_FIRST  \
# 0   0022000001  1610612744  Golden State  Warriors     201939      Stephen
# 1   0022000001  1610612744  Golden State  Warriors     201939      Stephen
# 2   0022000001  1610612744  Golden State  Warriors     202954         Brad
# 3   0022000001  1610612744  Golden State  Warriors     202954         Brad
# 4   0022000001  1610612744  Golden State  Warriors     203145         Kent
# 5   0022000001  1610612744  Golden State  Warriors     203145         Kent
# 6   0022000001  1610612744  Golden State  Warriors     203952       Andrew
# 7   0022000001  1610612744  Golden State  Warriors     203952       Andrew
# 8   0022000001  1610612744  Golden State  Warriors     203952       Andrew
# 9   0022000001  1610612744  Golden State  Warriors     203952       Andrew
# 10  0022000001  1610612744  Golden State  Warriors    1626162        Kelly
# ...

# %%
from nba_api.stats.endpoints import leaguedashlineups

ld = leaguedashlineups.LeagueDashLineups(season='2020-21')
ld.get_data_frames()[0]
# Out:
#      GROUP_SET                                   GROUP_ID  \
# 0      Lineups    -101108-203109-1626164-1628969-1629028-
# 1      Lineups      -201980-202699-203552-203954-1627732-
# 2      Lineups    -202339-203500-1627742-1628366-1629627-
# 3      Lineups     -201144-202711-203497-1626220-1628378-
# 4      Lineups      -203457-203493-203901-203944-1629628-
# ...        ...                                        ...
# 1995   Lineups  -1627774-1627823-1629162-1629669-1629675-
# 1996   Lineups  -1626157-1627823-1629006-1629669-1629675-
# 1997   Lineups     -201152-202696-203107-1629632-1630172-
# 1998   Lineups    -201609-203473-1629134-1629622-1629644-
# 1999   Lineups   -202339-1628404-1628411-1629637-1630184-
#
#                                              GROUP_NAME     TEAM_ID  \
# 0     C. Paul - J. Crowder - D. Booker - M. Bridges ...  1610612756
# 1     D. Green - T. Harris - S. Curry - J. Embiid - ...  1610612755
# ...

# %%
from nba_api.stats.endpoints import boxscoreplayertrackv2

bs = boxscoreplayertrackv2.BoxScorePlayerTrackV2(game_id= '0022000002')
bs1 = bs.get_data_frames()[0]

# %%
bs1
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0   0022000002  1610612746               LAC           LA     202695
# 1   0022000002  1610612746               LAC           LA     201587
# 2   0022000002  1610612746               LAC           LA     201586
# 3   0022000002  1610612746               LAC           LA     202331
# 4   0022000002  1610612746               LAC           LA     201976
# 5   0022000002  1610612746               LAC           LA    1627826
# 6   0022000002  1610612746               LAC           LA     202335
# 7   0022000002  1610612746               LAC           LA     101150
# 8   0022000002  1610612746               LAC           LA    1628379
# 9   0022000002  1610612746               LAC           LA    1629611
# 10  0022000002  1610612746               LAC           LA     202704
# 11  0022000002  1610612746               LAC           LA    1629662
# 12  0022000002  1610612746               LAC           LA    1629599
# ...

# %%
bs1.loc[bs1['START_POSITION'].isin(['F', 'C', 'G'])]
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0   0022000002  1610612746               LAC           LA     202695
# 1   0022000002  1610612746               LAC           LA     201587
# 2   0022000002  1610612746               LAC           LA     201586
# 3   0022000002  1610612746               LAC           LA     202331
# 4   0022000002  1610612746               LAC           LA     201976
# 14  0022000002  1610612747               LAL  Los Angeles       2544
# 15  0022000002  1610612747               LAL  Los Angeles     203076
# 16  0022000002  1610612747               LAL  Los Angeles     201188
# 17  0022000002  1610612747               LAL  Los Angeles     203484
# 18  0022000002  1610612747               LAL  Los Angeles     203471
#
#                  PLAYER_NAME START_POSITION COMMENT    MIN   SPD  DIST  ORBC  \
# 0              Kawhi Leonard              F          34:00  4.22  2.55     2
# ...

# %%
from nba_api.stats.endpoints import teamdashboardbyteamperformance

tt = teamdashboardbyteamperformance.TeamDashboardByTeamPerformance(team_id = 1610612747, season='2020-21')

# %%
tt.get_data_frames()[0]
# Out:
#   GROUP_SET GROUP_VALUE  GP   W   L  W_PCT     MIN   FGM   FGA  FG_PCT  FG3M  \
# 0   Overall     2020-21  72  42  30  0.583  3491.0  2925  6197   0.472   796
#
#    FG3A  FG3_PCT   FTM   FTA  FT_PCT  OREB  DREB   REB   AST     TOV  STL  \
# 0  2248    0.354  1241  1679   0.739   695  2490  3185  1775  1095.0  562
#
#    BLK  BLKA    PF   PFD   PTS  PLUS_MINUS  GP_RANK  W_RANK  L_RANK  \
# 0  386   327  1377  1530  7887       201.0        1       1       1
#
#    W_PCT_RANK  MIN_RANK  FGM_RANK  FGA_RANK  FG_PCT_RANK  FG3M_RANK  \
# 0           1         1         1         1            1          1
#
#    FG3A_RANK  FG3_PCT_RANK  FTM_RANK  FTA_RANK  FT_PCT_RANK  OREB_RANK  \
# 0          1             1         1         1            1          1
#
#    DREB_RANK  REB_RANK  AST_RANK  TOV_RANK  STL_RANK  BLK_RANK  BLKA_RANK  \
# 0          1         1         1         1         1         1          1
#
#    PF_RANK  PFD_RANK  PTS_RANK  PLUS_MINUS_RANK  CFID CFPARAMS
# ...

# %%
from nba_api.stats.endpoints import teamgamelogs

gl = teamgamelogs.TeamGameLogs()
gl.get_data_frames()[0]
# Out:
#      SEASON_YEAR     TEAM_ID TEAM_ABBREVIATION               TEAM_NAME  \
# 0        2016-17  1610612757               POR  Portland Trail Blazers
# 1        2016-17  1610612752               NYK         New York Knicks
# 2        2016-17  1610612742               DAL        Dallas Mavericks
# 3        2016-17  1610612745               HOU         Houston Rockets
# 4        2016-17  1610612750               MIN  Minnesota Timberwolves
# ...          ...         ...               ...                     ...
# 2455     2016-17  1610612752               NYK         New York Knicks
# 2456     2016-17  1610612739               CLE     Cleveland Cavaliers
# 2457     2016-17  1610612762               UTA               Utah Jazz
# 2458     2016-17  1610612759               SAS       San Antonio Spurs
# 2459     2016-17  1610612757               POR  Portland Trail Blazers
#
#          GAME_ID            GAME_DATE      MATCHUP WL   MIN  FGM  FGA  FG_PCT  \
# ...

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2

pbs = boxscoreadvancedv2.BoxScoreAdvancedV2('0021601220')

# %%
pbs = pbs.get_data_frames()[0]

# %%
pbs
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0021601220  1610612755               PHI  Philadelphia    1626147
# 1   0021601220  1610612755               PHI  Philadelphia    1627816
# 2   0021601220  1610612755               PHI  Philadelphia    1626158
# 3   0021601220  1610612755               PHI  Philadelphia    1627789
# 4   0021601220  1610612755               PHI  Philadelphia     204456
# 5   0021601220  1610612755               PHI  Philadelphia     201945
# 6   0021601220  1610612755               PHI  Philadelphia     203917
# 7   0021601220  1610612755               PHI  Philadelphia    1627848
# 8   0021601220  1610612755               PHI  Philadelphia     201168
# 9   0021601220  1610612755               PHI  Philadelphia     203496
# 10  0021601220  1610612755               PHI  Philadelphia    1626143
# 11  0021601220  1610612755               PHI  Philadelphia     200771
# ...

# %%
starters = pbs.loc[pbs['START_POSITION'].isin(['F', 'C', 'G'])]

# %%
list(starters['PLAYER_ID'])
# Out:
# [1626147,
#  1627816,
#  1626158,
#  1627789,
#  204456,
#  2546,
#  1626254,
#  1626195,
#  1627758,
#  201584]

# %%
starters
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0021601220  1610612755               PHI  Philadelphia    1626147
# 1   0021601220  1610612755               PHI  Philadelphia    1627816
# 2   0021601220  1610612755               PHI  Philadelphia    1626158
# 3   0021601220  1610612755               PHI  Philadelphia    1627789
# 4   0021601220  1610612755               PHI  Philadelphia     204456
# 13  0021601220  1610612752               NYK      New York       2546
# 14  0021601220  1610612752               NYK      New York    1626254
# 15  0021601220  1610612752               NYK      New York    1626195
# 16  0021601220  1610612752               NYK      New York    1627758
# 17  0021601220  1610612752               NYK      New York     201584
#
#                 PLAYER_NAME  NICKNAME START_POSITION COMMENT    MIN  \
# 0           Justin Anderson    Justin              F          34:35
# ...

# %%
for player in pbs['PLAYER_NAME']:
    if pbs['START_POSITION'].isin(['F', 'C', 'G']):
        print(pbs['START_POSITION'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-130-9d90cf0dbb1f> in <module>
#       1 for player in pbs['PLAYER_NAME']:
# ----> 2     if pbs['START_POSITION'].isin(['F', 'C', 'G']):
#       3         print(pbs['START_POSITION'])
#
# ~/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1327
#    1328     def __nonzero__(self):
# -> 1329         raise ValueError(
#    1330             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1331             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().
