# %%
import pickle
import pandas as pd

# %%
def merge_expanding_means_ind(df):
    exp_lists = {}
    exp_ind = {}
    for column in rol_col_ind:
        exp_lists[column] = []
        exp_ind[column] = []

    exp_series_dict = {}
    for column in rol_col_ind:
        exp_series_dict[f'Season{column}'] = []
        
    for column in rol_col_ind:
    
        for team in df.groupby('PLAYER_ID').groups:
            team_rol = df.groupby('PLAYER_ID')[column].expanding().mean()[team].shift()
            exp_lists[column].extend(list(team_rol.values))
            exp_ind[column].extend(list(team_rol.index))
    
        exp_series_dict[f'Season{column}'] = pd.Series(exp_lists[column], exp_ind[column], name = f"{column} Season")
    
    for series in exp_series_dict:
        df = df.merge(exp_series_dict[series], left_index=True, right_index=True)
        
    return df

# %%
rol_col_ind = ['OFF_RATING', 'DEF_RATING', 'NET_RATING', 'EFG_PCT',
 'TS_PCT', 'PACE', 'PIE']

# %%
with open('data/pickles/starters21.p', 'rb') as readfile: 
    starters21 = pickle.load(readfile)
    
with open('data/pickles/starters20.p', 'rb') as readfile: 
    starters20 = pickle.load(readfile)
    
with open('data/pickles/starters19.p', 'rb') as readfile: 
    starters19 = pickle.load(readfile)
    
with open('data/pickles/starters18.p', 'rb') as readfile: 
    starters18 = pickle.load(readfile)
    
with open('data/pickles/starters17.p', 'rb') as readfile: 
    starters17 = pickle.load(readfile)

# %%
starters21
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0022000001  1610612744               GSW  Golden State     203952
# 1   0022000001  1610612744               GSW  Golden State    1629672
# 2   0022000001  1610612744               GSW  Golden State    1630164
# 3   0022000001  1610612744               GSW  Golden State    1626162
# 4   0022000001  1610612744               GSW  Golden State     201939
# ..         ...         ...               ...           ...        ...
# 15  0022001080  1610612764               WAS    Washington     202722
# 16  0022001080  1610612764               WAS    Washington    1629060
# 17  0022001080  1610612764               WAS    Washington     203458
# 18  0022001080  1610612764               WAS    Washington     203078
# 19  0022001080  1610612764               WAS    Washington     201566
#
#           PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  TM_TOV_PCT  \
# 0      Andrew Wiggins   Andrew              F          31:14  ...        17.4
# 1       Eric Paschall     Eric              F          21:33  ...         0.0
# 2       James Wiseman    James              C          24:17  ...         5.6
# 3     Kelly Oubre Jr.    Kelly              G          25:39  ...        15.8
# 4       Stephen Curry  Stephen              G          30:19  ...         8.3
# ..                ...      ...            ...     ...    ...  ...         ...
# 15      Davis Bertans    Davis              F          26:58  ...        11.1
# 16      Rui Hachimura      Rui              F          34:21  ...         0.0
# 17           Alex Len     Alex              C           4:40  ...         0.0
# 18       Bradley Beal  Bradley              G          34:37  ...         8.3
# 19  Russell Westbrook  Russell              G          40:11  ...         8.8
#
#     EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  E_PACE    PACE  PACE_PER40  POSS  \
# 0     0.313   0.366    0.259      0.262  111.88  109.11       90.93    72
# 1     0.417   0.436    0.127      0.130  112.22  111.37       92.81    49
# 2     0.577   0.575    0.286      0.290  116.62  114.65       95.54    58
# 3     0.214   0.214    0.243      0.244  120.78  118.83       99.03    63
# 4     0.381   0.439    0.313      0.314  119.41  117.16       97.64    74
# ..      ...     ...      ...        ...     ...     ...         ...   ...
# 15    0.688   0.688    0.143      0.141  111.53  107.69       89.74    60
# 16    0.667   0.667    0.152      0.153  107.10  104.80       87.34    74
# 17    0.000   0.000    0.000      0.000  111.91  108.00       90.00    11
# 18    0.352   0.416    0.381      0.388  105.07  104.02       86.68    76
# 19    0.467   0.567    0.240      0.248  106.55  104.52       87.10    87
#
#       PIE
# 0  -0.044
# 1   0.012
# 2   0.166
# 3   0.000
# 4   0.127
# ..    ...
# 15  0.063
# 16  0.106
# 17  0.000
# 18  0.059
# 19  0.177
#
# [10800 rows x 32 columns]

# %%
merge_expanding_means_ind(starters21)

# %%
starters21
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a4802d393022> in <module>
# ----> 1 starters21
#
# NameError: name 'starters21' is not defined
