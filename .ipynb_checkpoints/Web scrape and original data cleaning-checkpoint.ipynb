# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import os
from selenium import webdriver
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib.ticker as ticker
import pickle

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 30)

# %%
pip install nba_api
# Out:
# Requirement already satisfied: nba_api in /Users/dillmedd/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages (1.1.9)
# Requirement already satisfied: requests in /Users/dillmedd/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages (from nba_api) (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in /Users/dillmedd/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages (from requests->nba_api) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/dillmedd/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages (from requests->nba_api) (2021.5.30)
# Requirement already satisfied: chardet<4,>=3.0.2 in /Users/dillmedd/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages (from requests->nba_api) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /Users/dillmedd/opt/anaconda3/envs/learn-env/lib/python3.8/site-packages (from requests->nba_api) (1.25.10)
# Note: you may need to restart the kernel to use updated packages.

# %%
from nba_api.stats.endpoints import playercareerstats
# Anthony Davis
career = playercareerstats.PlayerCareerStats(player_id='203076')
career.get_data_frames()[0]
# Out:
#    PLAYER_ID SEASON_ID LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION  PLAYER_AGE  \
# 0     203076   2012-13        00  1610612740               NOH        20.0
# 1     203076   2013-14        00  1610612740               NOP        21.0
# 2     203076   2014-15        00  1610612740               NOP        22.0
# 3     203076   2015-16        00  1610612740               NOP        23.0
# 4     203076   2016-17        00  1610612740               NOP        24.0
# 5     203076   2017-18        00  1610612740               NOP        25.0
# 6     203076   2018-19        00  1610612740               NOP        26.0
# 7     203076   2019-20        00  1610612747               LAL        27.0
# 8     203076   2020-21        00  1610612747               LAL        28.0
# 9     203076   2021-22        00  1610612747               LAL        28.0
#
#    GP  GS     MIN  FGM  ...  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV   PF  \
# 0  64  60  1846.0  349  ...   0.751   165   357  522   63   75  112   89  158
# 1  67  66  2358.0  522  ...   0.791   207   466  673  105   89  189  109  200
# 2  68  68  2455.0  642  ...   0.805   173   523  696  149  100  200   95  141
# 3  61  61  2164.0  560  ...   0.758   130   497  627  116   78  125  121  148
# 4  75  75  2708.0  770  ...   0.802   172   712  884  157   94  167  181  168
# 5  75  75  2727.0  780  ...   0.828   187   644  831  174  115  193  162  159
# 6  56  56  1850.0  530  ...   0.794   174   498  672  218   88  135  112  132
# 7  62  62  2131.0  551  ...   0.846   142   435  577  200   91  143  154  156
# 8  36  36  1162.0  301  ...   0.738    62   224  286  110   45   59   74   60
# 9   1   1    39.0   15  ...   0.286     2     9   11    2    1    2    0    0
#
#     PTS
# 0   867
# 1  1394
# 2  1656
# 3  1481
# 4  2099
# 5  2110
# 6  1452
# 7  1618
# 8   786
# 9    33
#
# [10 rows x 27 columns]

# %%
from nba_api.stats.endpoints import playerestimatedmetrics

player = playerestimatedmetrics.PlayerEstimatedMetrics(season='2020-21')
player.get_data_frames()[0]
# Out:
#      PLAYER_ID           PLAYER_NAME  GP  W  L  W_PCT   MIN  E_OFF_RATING  \
# 0         2617         Udonis Haslem   1  1  0  1.000   2.7         158.2
# 1      1629665          Jalen Lecque   4  2  2  0.500   3.0          69.8
# 2      1627737       Marquese Chriss   2  0  2  0.000  13.4          74.8
# 3      1629034          Ray Spalding   2  0  2  0.000   9.4          91.7
# 4      1628961  Kostas Antetokounmpo  15  6  9  0.400   3.7         103.0
# ..         ...                   ...  .. .. ..    ...   ...           ...
# 535    1627775         Patrick McCaw   5  2  3  0.400   6.7         105.5
# 536     203460        Andre Roberson   5  4  1  0.800  12.6         105.5
# 537     203943           Noah Vonleh   4  3  1  0.750   2.7          91.0
# 538    1630238           Malik Fitts   3  3  0  1.000   3.6          88.3
# 539    1630203          Grant Riller   7  2  5  0.286   3.9          98.7
#
#      E_DEF_RATING  E_NET_RATING  E_AST_RATIO  E_OREB_PCT  E_DREB_PCT  \
# 0            85.4          72.9          0.0       0.000       0.333
# 1            92.7         -22.9         16.2       0.111       0.231
# 2           124.2         -49.3         10.1       0.094       0.400
# 3           108.3         -16.6          0.0       0.083       0.100
# 4            89.1          13.9          3.6       0.070       0.227
# ..            ...           ...          ...         ...         ...
# 535         133.5         -28.0         63.3       0.030       0.087
# 536         116.6         -11.1         19.2       0.115       0.151
# 537         161.7         -70.7         16.7       0.000       0.143
# 538         121.8         -33.5          0.0       0.000       0.300
# 539         110.9         -12.2         18.8       0.000       0.043
#
#      E_REB_PCT  E_TOV_PCT  E_USG_PCT  E_PACE  GP_RANK  W_RANK  L_RANK  \
# 0        0.333      0.000      0.316  130.44      537     515       1
# 1        0.161      0.000      0.278  112.83      519     501      15
# 2        0.228     10.121      0.252  112.36      532     531      15
# 3        0.091     38.071      0.156  111.46      532     531      15
# 4        0.154     39.683      0.175  110.26      458     456      88
# ..         ...        ...        ...     ...      ...     ...     ...
# 535      0.054      0.000      0.031   95.13      512     501      27
# 536      0.132      9.579      0.123   95.06      512     474       6
# 537      0.071     33.333      0.239   94.78      519     482       6
# 538      0.167      0.000      0.133   93.28      527     482       1
# 539      0.021      6.250      0.225   92.64      501     501      50
#
#      W_PCT_RANK  MIN_RANK  E_OFF_RATING_RANK  E_DEF_RATING_RANK  \
# 0             1       535                  1                  5
# 1           251       532                536                 14
# 2           531       392                533                533
# 3           531       447                516                177
# 4           382       525                414                  8
# ..          ...       ...                ...                ...
# 535         382       484                358                536
# 536          12       404                358                514
# 537          18       534                517                539
# 538           1       526                525                528
# 539         472       520                477                336
#
#      E_NET_RATING_RANK  E_AST_RATIO_RANK  E_OREB_PCT_RANK  E_DREB_PCT_RANK  \
# 0                    1               531              518                7
# 1                  517               253               48               61
# 2                  536               443               69                1
# 3                  505               531               89              437
# 4                   12               524              119               64
# ..                 ...               ...              ...              ...
# 535                527                 1              292              484
# 536                472               166               42              244
# 537                538               237              518              272
# 538                531               531              518               19
# 539                479               175              518              532
#
#      E_REB_PCT_RANK  E_TOV_PCT_RANK  E_USG_PCT_RANK  E_PACE_RANK
# 0                 1               1              12            1
# 1                60               1              39            2
# 2                12              31              61            3
# 3               260             536             370            4
# 4                72             536             275            5
# ..              ...             ...             ...          ...
# 535             477               1             540          536
# 536             113              31             481          537
# 537             365             530              79          538
# 538              55               1             457          539
# 539             535              31             114          540
#
# [540 rows x 32 columns]

# %%
from nba_api.stats.endpoints import leaguedashplayerstats

players = leaguedashplayerstats.LeagueDashPlayerStats(season='2020-21', measure_type_detailed_defense='Advanced')
players.get_data_frames()[0]
# Out:
#      PLAYER_ID      PLAYER_NAME NICKNAME     TEAM_ID TEAM_ABBREVIATION   AGE  \
# 0       203932     Aaron Gordon    Aaron  1610612743               DEN  25.0
# 1      1628988    Aaron Holiday    Aaron  1610612754               IND  24.0
# 2      1630174    Aaron Nesmith    Aaron  1610612738               BOS  21.0
# 3      1627846      Abdel Nader    Abdel  1610612756               PHX  27.0
# 4      1629690      Adam Mokoka     Adam  1610612741               CHI  22.0
# ..         ...              ...      ...         ...               ...   ...
# 535    1627812     Yogi Ferrell     Yogi  1610612746               LAC  28.0
# 536    1629139    Yuta Watanabe     Yuta  1610612761               TOR  26.0
# 537     203897      Zach LaVine     Zach  1610612741               CHI  26.0
# 538    1630192       Zeke Nnaji     Zeke  1610612743               DEN  20.0
# 539    1629627  Zion Williamson     Zion  1610612740               NOP  20.0
#
#      GP   W   L  W_PCT   MIN  E_OFF_RATING  OFF_RATING  sp_work_OFF_RATING  \
# 0    50  29  21  0.580  27.7         111.8       112.5               112.5
# 1    66  30  36  0.455  17.8         110.2       110.1               110.1
# 2    46  22  24  0.478  14.5         108.9       108.6               108.6
# 3    24  16   8  0.667  14.8         106.6       106.7               106.7
# 4    14   3  11  0.214   4.0          85.1        83.2                83.2
# ..   ..  ..  ..    ...   ...           ...         ...                 ...
# 535  10   4   6  0.400  13.7         105.1       106.7               106.7
# 536  50  24  26  0.480  14.5         105.2       105.0               105.0
# 537  58  26  32  0.448  35.1         111.3       112.4               112.4
# 538  42  30  12  0.714   9.5         105.1       102.0               102.0
# 539  61  29  32  0.475  33.2         113.7       113.9               113.9
#
#      E_DEF_RATING  DEF_RATING  sp_work_DEF_RATING  E_NET_RATING  NET_RATING  \
# 0           110.4       110.4               110.4           1.4         2.1
# 1           109.9       110.3               110.3           0.2        -0.2
# 2           108.6       109.1               109.1           0.3        -0.5
# 3           103.2       101.7               101.7           3.4         5.0
# 4            93.4        90.3                90.3          -8.3        -7.1
# ..            ...         ...                 ...           ...         ...
# 535         107.2       107.1               107.1          -2.0        -0.4
# 536         107.7       107.8               107.8          -2.5        -2.7
# 537         111.6       113.1               113.1          -0.4        -0.8
# 538         113.2       112.5               112.5          -8.1       -10.5
# 539         112.2       111.7               111.7           1.4         2.1
#
#      sp_work_NET_RATING  AST_PCT  AST_TO  AST_RATIO  OREB_PCT  DREB_PCT  \
# 0                   2.1    0.165    1.66       19.6     0.055     0.150
# 1                  -0.2    0.139    1.86       18.5     0.012     0.060
# 2                  -0.5    0.047    1.00        9.7     0.041     0.146
# 3                   5.0    0.078    1.00       11.2     0.020     0.151
# 4                  -7.1    0.179    1.00       17.2     0.017     0.077
# ..                  ...      ...     ...        ...       ...       ...
# 535                -0.4    0.229    7.33       25.9     0.034     0.095
# 536                -2.7    0.079    2.11       15.9     0.046     0.171
# 537                -0.8    0.225    1.39       16.3     0.018     0.121
# 538               -10.5    0.037    1.43        7.8     0.034     0.129
# 539                 2.1    0.188    1.35       13.7     0.081     0.131
#
#      REB_PCT  TM_TOV_PCT  E_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT  E_USG_PCT  \
# 0      0.102        11.8       11.8    0.522   0.547    0.204      0.207
# 1      0.036         9.9       10.0    0.467   0.503    0.189      0.193
# 2      0.093         9.7        9.7    0.551   0.573    0.133      0.138
# 3      0.088        11.2       11.2    0.569   0.605    0.183      0.189
# 4      0.045        17.2       17.0    0.395   0.386    0.171      0.186
# ..       ...         ...        ...      ...     ...      ...        ...
# 535    0.065         3.5        3.5    0.430   0.459    0.193      0.201
# 536    0.106         7.5        7.5    0.539   0.565    0.121      0.125
# 537    0.071        11.7       11.7    0.596   0.634    0.302      0.308
# 538    0.080         5.5        5.5    0.596   0.615    0.126      0.131
# 539    0.106        10.1       10.0    0.616   0.649    0.287      0.296
#
#      E_PACE    PACE  PACE_PER40  sp_work_PACE    PIE  POSS  FGM   FGA  FGM_PG  \
# 0     99.83   99.48       82.90         99.48  0.095  2868  231   499     4.6
# 1    104.48  104.34       86.95        104.34  0.057  2560  170   436     2.6
# 2    101.20  101.13       84.28        101.13  0.060  1409   78   178     1.7
# 3    102.30  102.96       85.80        102.96  0.092   757   57   116     2.4
# 4    103.47  106.38       88.65        106.38  0.025   125    7    19     0.5
# ..      ...     ...         ...           ...    ...   ...  ...   ...     ...
# 535   99.86   99.17       82.64         99.17  0.094   283   20    57     2.0
# 536  101.71  101.77       84.81        101.77  0.089  1533   79   180     1.6
# 537  102.54  101.34       84.45        101.34  0.140  4304  569  1123     9.8
# 538  100.70  102.52       85.43        102.52  0.074   852   50   104     1.2
# 539  103.14  103.30       86.09        103.30  0.161  4358  634  1037    10.4
#
#      FGA_PG  FG_PCT  GP_RANK  W_RANK  L_RANK  W_PCT_RANK  MIN_RANK  \
# 0      10.0   0.463      238     158     258         167       135
# 1       6.6   0.390       70     143     490         318       310
# 2       3.9   0.438      268     252     309         286       376
# 3       4.8   0.491      417     331      76          79       370
# 4       1.4   0.368      463     482     111         506       517
# ..      ...     ...      ...     ...     ...         ...       ...
# 535     5.7   0.351      485     474      61         382       387
# 536     3.6   0.439      238     223     341         284       377
# 537    19.4   0.507      157     201     437         325        14
# 538     2.5   0.481      303     143     120          43       446
# 539    17.0   0.611      124     158     437         292        44
#
#      E_OFF_RATING_RANK  OFF_RATING_RANK  sp_work_OFF_RATING_RANK  \
# 0                  139              133                      133
# 1                  189              203                      203
# 2                  229              255                      255
# 3                  318              315                      315
# 4                  530              528                      528
# ..                 ...              ...                      ...
# 535                368              316                      316
# 536                366              364                      364
# 537                156              138                      138
# 538                369              431                      431
# 539                 86               98                       98
#
#      E_DEF_RATING_RANK  DEF_RATING_RANK  sp_work_DEF_RATING_RANK  \
# 0                  307              291                      291
# 1                  281              287                      287
# 2                  198              228                      228
# 3                   52               48                       48
# 4                   17               13                       13
# ..                 ...              ...                      ...
# 535                132              137                      137
# 536                154              164                      164
# 537                370              424                      424
# 538                437              398                      398
# 539                393              361                      361
#
#      E_NET_RATING_RANK  NET_RATING_RANK  sp_work_NET_RATING_RANK  \
# 0                  179              170                      170
# 1                  228              238                      238
# 2                  226              255                      255
# 3                  132               95                       95
# 4                  440              423                      423
# ..                 ...              ...                      ...
# 535                294              246                      246
# 536                308              310                      310
# 537                247              260                      260
# 538                436              470                      470
# 539                180              166                      166
#
#      AST_PCT_RANK  AST_TO_RANK  AST_RATIO_RANK  OREB_PCT_RANK  DREB_PCT_RANK  \
# 0             147          269             158            139            199
# 1             198          226             185            470            525
# 2             496          424             458            204            209
# 3             390          424             414            362            194
# 4             130          424             221            406            486
# ..            ...          ...             ...            ...            ...
# 535            76            3              63            240            406
# 536           384          162             265            177            126
# 537            81          335             248            391            291
# 538           513          325             496            243            267
# 539           120          346             336             74            257
#
#      REB_PCT_RANK  TM_TOV_PCT_RANK  E_TOV_PCT_RANK  EFG_PCT_RANK  TS_PCT_RANK  \
# 0             172              402             397           275          304
# 1             526              288             294           434          423
# 2             210              274             278           184          214
# 3             231              363             363           129          113
# 4             496              515             514           501          510
# ..            ...              ...             ...           ...          ...
# 535           357               17              17           469          482
# 536           156              111             114           221          237
# 537           314              395             391            76           62
# 538           270               40              42            73           87
# 539           154              306             300            48           41
#
#      USG_PCT_RANK  E_USG_PCT_RANK  E_PACE_RANK  PACE_RANK  sp_work_PACE_RANK  \
# 0             152             156          406        421                421
# 1             203             209           72         87                 87
# 2             444             442          295        290                290
# 3             228             231          199        152                152
# 4             274             238          115         36                 36
# ..            ...             ...          ...        ...                ...
# 535           185             179          403        448                448
# 536           476             478          248        243                243
# 537            15              16          181        268                268
# 538           466             462          339        186                186
# 539            23              21          139        129                129
#
#      PIE_RANK  FGM_RANK  FGA_RANK  FGM_PG_RANK  FGA_PG_RANK  FG_PCT_RANK  \
# 0         212       154       153          134          127          216
# 1         450       213       175          287          243          431
# 2         440       343       341          386          382          288
# 3         231       370       378          310          323          141
# 4         515       493       489          508          510          469
# ..        ...       ...       ...          ...          ...          ...
# 535       220       451       441          352          289          489
# 536       256       342       339          401          404          286
# 537        43        12        13            7            9          111
# 538       360       379       386          436          457          161
# 539        22         6        26            3           34           38
#
#      CFID            CFPARAMS
# 0       5   203932,1610612743
# 1       5  1628988,1610612754
# 2       5  1630174,1610612738
# 3       5  1627846,1610612756
# 4       5  1629690,1610612741
# ..    ...                 ...
# 535     5  1627812,1610612746
# 536     5  1629139,1610612761
# 537     5   203897,1610612741
# 538     5  1630192,1610612743
# 539     5  1629627,1610612740
#
# [540 rows x 80 columns]

# %%
from nba_api.stats.endpoints import leaguegamefinder

gamefinder = leaguegamefinder.LeagueGameFinder()
games = gamefinder.get_data_frames()[0]
games.head(5)
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION              TEAM_NAME     GAME_ID  \
# 0     12021  1610612744               GSW  Golden State Warriors  0012100047
# 1     12021  1610612747               LAL     Los Angeles Lakers  0012100047
# 2     12021  1610612764               WAS     Washington Wizards  0012100046
# 3     12021  1610612761               TOR        Toronto Raptors  0012100046
# 4     12021  1610612755               PHI     Philadelphia 76ers  0012100041
#
#     GAME_DATE      MATCHUP WL  MIN  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0  2021-10-12    GSW @ LAL  W  239  111   42   99   0.424    11    49
# 1  2021-10-12  LAL vs. GSW  L  239   99   36   87   0.414    10    31
# 2  2021-10-12  WAS vs. TOR  L  240  108   38   88   0.432    17    43
# 3  2021-10-12    TOR @ WAS  W  241  113   39   95   0.411    15    35
# 4  2021-10-11  PHI vs. BKN  W  240  115   44   89   0.494    13    36
#
#    FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0    0.224   16   22   0.727     9    42   51   29   10    5   12  19
# 1    0.323   17   22   0.773     6    46   52   22    9    6   20  22
# 2    0.395   15   20   0.750     9    43   52   27    6    7   15  18
# 3    0.429   20   27   0.741    14    42   56   26    8    6   11  18
# 4    0.361   14   25   0.560     9    32   41   25   20    2   15  18
#
#    PLUS_MINUS
# 0        12.0
# 1       -12.0
# 2        -5.0
# 3         5.0
# 4        11.0

# %% [raw]
# Use list of NBA teams to filter Boxscore Dataframe to only NBA games

# %%
nba_teams = ['Golden State Warriors','Boston Celtics','Toronto Raptors','Houston Rockets','Cleveland Cavaliers','Miami Heat','San Antonio Spurs','Milwaukee Bucks','Portland Trail Blazers','Utah Jazz','Atlanta Hawks','Los Angeles Lakers','Philadelphia 76ers','Memphis Grizzlies','Denver Nuggets','Washington Wizards','Dallas Mavericks','LA Clippers','Oklahoma City Thunder','Brooklyn Nets','Indiana Pacers','Phoenix Suns','New Orleans Pelicans','Chicago Bulls','Sacramento Kings','Orlando Magic','Charlotte Hornets','Detroit Pistons','Minnesota Timberwolves','New York Knicks']

# %%
games_nba = games.loc[games['TEAM_NAME'].apply(lambda x: x in (nba_teams))]

# %% [raw]
# Filtering dataframes by season and only including Regular Season games

# %%
season21 = games_nba.loc[games_nba.SEASON_ID == '22020'].reset_index(drop=True)

season20 = games_nba.loc[games_nba.SEASON_ID == '22019'].reset_index(drop=True)

season19 = games_nba.loc[games_nba.SEASON_ID == '22018'].head(2460).reset_index(drop=True)

season18 = games_nba.loc[games_nba.SEASON_ID == '22017'].head(2460).reset_index(drop=True)

season17 = games_nba.loc[games_nba.SEASON_ID == '22016'].head(2460).reset_index(drop=True)

season16 = games_nba.loc[games_nba.SEASON_ID == '22015'].head(2460).reset_index(drop=True)

# %%
season20 = season20.loc[season20.GAME_DATE >= '2019-10-22']
season20 = season20.reset_index(drop=True)

# %%
#with open('data/pickles/season21.p', 'wb') as writefile: 
   # pickle.dump(season21, writefile)
    
with open('data/pickles/season20.p', 'wb') as writefile: 
    pickle.dump(season20, writefile)
    
with open('data/pickles/season19.p', 'wb') as writefile: 
    pickle.dump(season19, writefile)
    
with open('data/pickles/season18.p', 'wb') as writefile: 
    pickle.dump(season18, writefile)
    
with open('data/pickles/season17.p', 'wb') as writefile: 
    pickle.dump(season17, writefile)
    
with open('data/pickles/season16.p', 'wb') as writefile: 
    pickle.dump(season16, writefile)

# %%
def combine_team_games(df, keep_method='home'):
    '''Combine a TEAM_ID-GAME_ID unique table into rows by game. Slow.

        Parameters
        ----------
        df : Input DataFrame.
        keep_method : {'home', 'away', 'winner', 'loser', ``None``}, default 'home'
            - 'home' : Keep rows where TEAM_A is the home team.
            - 'away' : Keep rows where TEAM_A is the away team.
            - 'winner' : Keep rows where TEAM_A is the losing team.
            - 'loser' : Keep rows where TEAM_A is the winning team.
            - ``None`` : Keep all rows. Will result in an output DataFrame the same
                length as the input DataFrame.
                
        Returns
        -------
        result : DataFrame
    '''
    # Join every row to all others with the same game ID.
    joined = pd.merge(df, df, suffixes=['_A', '_B'],
                      on=['SEASON_ID', 'GAME_ID', 'GAME_DATE'])
    # Filter out any row that is joined to itself.
    result = joined[joined.TEAM_ID_A != joined.TEAM_ID_B]
    # Take action based on the keep_method flag.
    if keep_method is None:
        # Return all the rows.
        pass
    elif keep_method.lower() == 'home':
        # Keep rows where TEAM_A is the home team.
        result = result[result.MATCHUP_A.str.contains(' vs. ')]
    elif keep_method.lower() == 'away':
        # Keep rows where TEAM_A is the away team.
        result = result[result.MATCHUP_A.str.contains(' @ ')]
    elif keep_method.lower() == 'winner':
        result = result[result.WL_A == 'W']
    elif keep_method.lower() == 'loser':
        result = result[result.WL_A == 'L']
    else:
        raise ValueError(f'Invalid keep_method: {keep_method}')
    return result

# %% [raw]
# Combine games on dataframes for purpose of creating df with advanced stats and four factors stats for each game

# %%
loop_season21 = combine_team_games(season21)
loop_season20 = combine_team_games(season20)
loop_season19 = combine_team_games(season19)
loop_season18 = combine_team_games(season18)
loop_season17 = combine_team_games(season17)
loop_season16 = combine_team_games(season16)

# %%
loop_season21.reset_index(inplace=True, drop=True)
loop_season20.reset_index(inplace=True, drop=True)
loop_season19.reset_index(inplace=True, drop=True)
loop_season18.reset_index(inplace=True, drop=True)
loop_season17.reset_index(inplace=True, drop=True)
loop_season16.reset_index(inplace=True, drop=True)

# %% [raw]
# Create new dataframes for advanced boxscore stats, four_factors stats using a for loop to append each game's stats together

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2
#Advanced Stats by gameID
boxscore21 = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = loop_season21['GAME_ID'][0])
bs_df21 = boxscore21.get_data_frames()[1]

# %%
for n in range(1, len(loop_season21)):
    dfn = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = (loop_season21['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    bs_df21 = bs_df21.append(dfn2)
    
    
with open('data/pickles/boxscoreadv21.p', 'wb') as writefile: 
    pickle.dump(bs_df21, writefile)

# %%
from nba_api.stats.endpoints import boxscorefourfactorsv2
#FourFactors
ffboxscore21 = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season21['GAME_ID'][0]))
ff_df21 = ffboxscore.get_data_frames()[1]

# %%
for n in range(1, len(loop_season21)):
    dfn = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season21['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    ff_df21 = ff_df21.append(dfn2)
    
with open('data/pickles/fourfactors21.p', 'wb') as writefile: 
    pickle.dump(ff_df21, writefile)

# %%
with open('data/pickles/fourfactors21.p', 'wb') as writefile: 
    pickle.dump(ff_df21, writefile)

# %% [markdown]
# Do the same with seasons 16-20

# %%
boxscore20 = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = loop_season20['GAME_ID'][0])
boxscore19 = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = loop_season19['GAME_ID'][0])
boxscore18 = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = loop_season18['GAME_ID'][0])
boxscore17 = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = loop_season17['GAME_ID'][0])
boxscore16 = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = loop_season16['GAME_ID'][0])
bs_df20 = boxscore20.get_data_frames()[1]
bs_df19 = boxscore19.get_data_frames()[1]
bs_df18 = boxscore18.get_data_frames()[1]
bs_df17 = boxscore17.get_data_frames()[1]
bs_df16 = boxscore16.get_data_frames()[1]

# %%
ffboxscore20 = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season20['GAME_ID'][0]))
ff_df20 = ffboxscore20.get_data_frames()[1]

ffboxscore19 = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season19['GAME_ID'][0]))
ff_df19 = ffboxscore19.get_data_frames()[1]

ffboxscore18 = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season18['GAME_ID'][0]))
ff_df18 = ffboxscore.get_data_frames()[1]

ffboxscore17 = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season17['GAME_ID'][0]))
ff_df17 = ffboxscore.get_data_frames()[1]

ffboxscore16 = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season16['GAME_ID'][0]))
ff_df16 = ffboxscore.get_data_frames()[1]

# %%
for n in range(1, len(loop_season20)):
    dfn = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = (loop_season20['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    bs_df20 = bs_df20.append(dfn2)
    
for n in range(1, len(loop_season20)):
    dfn = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season20['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    ff_df20 = ff_df20.append(dfn2)

# %%
with open('data/pickles/boxscoreadv20.p', 'wb') as writefile: 
    pickle.dump(bs_df20, writefile)

with open('data/pickles/fourfactors20.p', 'wb') as writefile: 
    pickle.dump(ff_df20, writefile)

# %%
for n in range(1, len(loop_season19)):
    dfn = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = (loop_season19['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    bs_df19 = bs_df19.append(dfn2)
    
for n in range(1, len(loop_season19)):
    dfn = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season19['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    ff_df19 = ff_df19.append(dfn2)

# %%
with open('data/pickles/boxscoreadv19.p', 'wb') as writefile: 
    pickle.dump(bs_df19, writefile)

with open('data/pickles/fourfactors19.p', 'wb') as writefile: 
    pickle.dump(ff_df19, writefile)

# %%
for n in range(1, len(loop_season18)):
    dfn = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = (loop_season18['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    bs_df18 = bs_df18.append(dfn2)
    
for n in range(1, len(loop_season18)):
    dfn = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season18['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    ff_df18 = ff_df18.append(dfn2)

# %%
with open('data/pickles/boxscoreadv18.p', 'wb') as writefile: 
    pickle.dump(bs_df18, writefile)

with open('data/pickles/fourfactors18.p', 'wb') as writefile: 
    pickle.dump(ff_df18, writefile)

# %%
for n in range(1, len(loop_season17)):
    dfn = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = (loop_season17['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    bs_df17 = bs_df17.append(dfn2)
    
for n in range(1, len(loop_season17)):
    dfn = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season17['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    ff_df17 = ff_df17.append(dfn2)

# %%
with open('data/pickles/boxscoreadv17.p', 'wb') as writefile: 
    pickle.dump(bs_df17, writefile)

with open('data/pickles/fourfactors17.p', 'wb') as writefile: 
    pickle.dump(ff_df17, writefile)

# %%
for n in range(1, len(loop_season16)):
    dfn = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = (loop_season16['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    bs_df16 = bs_df16.append(dfn2)

for n in range(1, len(loop_season16)):
    dfn = boxscorefourfactorsv2.BoxScoreFourFactorsV2(game_id = (loop_season16['GAME_ID'][n]))
    dfn2 = dfn.get_data_frames()[1]
    ff_df16 = ff_df16.append(dfn2)

# %%
with open('data/pickles/boxscoreadv16.p', 'wb') as writefile: 
    pickle.dump(bs_df16, writefile)

with open('data/pickles/fourfactors16.p', 'wb') as writefile: 
    pickle.dump(ff_df16, writefile)

# %%
df21 = pd.merge(season21, bs_df21, on = ['GAME_ID', 'TEAM_ID'], copy=False).drop(labels=['TEAM_NAME_y', 'TEAM_ABBREVIATION_y', 'MIN_y'], axis=1)
df21.head()
# Out:
#   SEASON_ID     TEAM_ID TEAM_ABBREVIATION_x         TEAM_NAME_x     GAME_ID  \
# 0     22020  1610612765                 DET     Detroit Pistons  0022001069
# 1     22020  1610612737                 ATL       Atlanta Hawks  0022001066
# 2     22020  1610612761                 TOR     Toronto Raptors  0022001079
# 3     22020  1610612755                 PHI  Philadelphia 76ers  0022001075
# 4     22020  1610612747                 LAL  Los Angeles Lakers  0022001072
#
#     GAME_DATE      MATCHUP WL  MIN_x  PTS  FGM  FGA  FG_PCT  FG3M  FG3A  \
# 0  2021-05-16  DET vs. MIA  L    240  107   40   86   0.465    11    35
# 1  2021-05-16  ATL vs. HOU  W    240  124   49   90   0.544     7    21
# 2  2021-05-16  TOR vs. IND  L    240  113   39   97   0.402    12    38
# 3  2021-05-16  PHI vs. ORL  W    241  128   46   94   0.489    19    40
# 4  2021-05-16    LAL @ NOP  W    238  110   45   96   0.469    11    35
#
#    FG3_PCT  FTM  FTA  FT_PCT  OREB  DREB  REB  AST  STL  BLK  TOV  PF  \
# 0    0.314   16   22   0.727     7    26   33   26    4    4   16  21
# 1    0.333   19   26   0.731    11    45   56   32   10    8   13  16
# 2    0.316   23   29   0.793    16    32   48   21    8    3   12  12
# 3    0.475   17   23   0.739     9    32   41   35    8    5   11  27
# 4    0.314    9   15   0.600     8    34   42   30   14    5    9  16
#
#    PLUS_MINUS     TEAM_CITY  E_OFF_RATING  OFF_RATING  E_DEF_RATING  \
# 0       -13.0       Detroit         102.2       110.3         121.5
# 1        29.0       Atlanta         119.9       120.4          89.8
# 2       -12.0       Toronto         106.8       107.6         118.0
# 3        11.0  Philadelphia         119.5       123.1         114.7
# 4        12.0   Los Angeles         105.2       110.0          97.8
#
#    DEF_RATING  E_NET_RATING  NET_RATING  AST_PCT  AST_TOV  AST_RATIO  \
# 0       122.4         -19.2       -12.1    0.650     1.63       18.9
# 1        93.1          30.1        27.3    0.653     2.46       21.9
# 2       117.9         -11.2       -10.3    0.538     1.75       14.7
# 3       112.5           4.8        10.6    0.761     2.92       23.2
# 4        99.0           7.4        11.0    0.667     3.00       21.0
#
#    OREB_PCT  DREB_PCT  REB_PCT  E_TM_TOV_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  \
# 0     0.245     0.769    0.477        15.285        16.5    0.529   0.559
# 1     0.298     0.750    0.559        12.568        12.6    0.583   0.611
# 2     0.322     0.729    0.505        11.346        11.4    0.464   0.515
# 3     0.196     0.744    0.447        11.202        11.5    0.590   0.615
# 4     0.278     0.791    0.505         9.560        10.0    0.526   0.536
#
#    USG_PCT  E_USG_PCT  E_PACE   PACE  PACE_PER40  POSS    PIE
# 0      1.0      0.193  101.74   97.5       81.25    97  0.386
# 1      1.0      0.199  104.62  102.5       85.42   103  0.678
# 2      1.0      0.202  105.84  105.5       87.92   105  0.428
# 3      1.0      0.195  104.58  104.0       86.67   104  0.539
# 4      1.0      0.199  102.42   99.5       82.92   100  0.560

# %%
from nba_api.stats.endpoints import boxscorescoringv2
#scoring stats
ssboxscore = boxscorescoringv2.BoxScoreScoringV2(game_id = '0021601229')
ssboxscore.get_data_frames()[1]
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION     TEAM_CITY     MIN  \
# 0  0021601229  1610612747    Lakers               LAL   Los Angeles  240:00
# 1  0021601229  1610612744  Warriors               GSW  Golden State  240:00
#
#    PCT_FGA_2PT  PCT_FGA_3PT  PCT_PTS_2PT  PCT_PTS_2PT_MR  PCT_PTS_3PT  \
# 0        0.817        0.183        0.787           0.128        0.128
# 1        0.600        0.400        0.532           0.147        0.330
#
#    PCT_PTS_FB  PCT_PTS_FT  PCT_PTS_OFF_TOV  PCT_PTS_PAINT  PCT_AST_2PM  \
# 0       0.340       0.085            0.287          0.660        0.568
# 1       0.211       0.138            0.174          0.385        0.552
#
#    PCT_UAST_2PM  PCT_AST_3PM  PCT_UAST_3PM  PCT_AST_FGM  PCT_UAST_FGM
# 0         0.432        0.500         0.500        0.561         0.439
# 1         0.448        0.833         0.167        0.634         0.366
