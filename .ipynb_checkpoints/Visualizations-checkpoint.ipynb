# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
pd.set_option('display.max_columns', None)

# %%
np.ascontiguousarray(x, dtype=np.float32)
# Out:
# array([0.        , 0.00200401, 0.00400802, 0.00601202, 0.00801603,
#        0.01002004, 0.01202405, 0.01402806, 0.01603206, 0.01803607,
#        0.02004008, 0.02204409, 0.0240481 , 0.0260521 , 0.02805611,
#        0.03006012, 0.03206413, 0.03406814, 0.03607215, 0.03807615,
#        0.04008016, 0.04208417, 0.04408818, 0.04609219, 0.04809619,
#        0.0501002 , 0.05210421, 0.05410822, 0.05611223, 0.05811623,
#        0.06012024, 0.06212425, 0.06412826, 0.06613226, 0.06813627,
#        0.07014028, 0.07214429, 0.0741483 , 0.0761523 , 0.07815631,
#        0.08016032, 0.08216433, 0.08416834, 0.08617234, 0.08817635,
#        0.09018036, 0.09218437, 0.09418838, 0.09619238, 0.09819639,
#        0.1002004 , 0.10220441, 0.10420842, 0.10621242, 0.10821643,
#        0.11022044, 0.11222445, 0.11422846, 0.11623246, 0.11823647,
#        0.12024048, 0.12224449, 0.1242485 , 0.1262525 , 0.12825651,
#        0.13026053, 0.13226452, 0.13426854, 0.13627255, 0.13827655,
#        0.14028056, 0.14228457, 0.14428858, 0.14629258, 0.1482966 ,
#        0.1503006 , 0.1523046 , 0.15430862, 0.15631263, 0.15831663,
#        0.16032064, 0.16232465, 0.16432866, 0.16633266, 0.16833667,
#        0.17034069, 0.17234468, 0.1743487 , 0.17635271, 0.1783567 ,
#        0.18036072, 0.18236473, 0.18436874, 0.18637274, 0.18837675,
#        0.19038077, 0.19238476, 0.19438878, 0.19639279, 0.19839679,
#        0.2004008 , 0.20240481, 0.20440882, 0.20641282, 0.20841683,
#        0.21042085, 0.21242484, 0.21442886, 0.21643287, 0.21843687,
#        0.22044088, 0.22244489, 0.2244489 , 0.2264529 , 0.22845691,
#        0.23046093, 0.23246492, 0.23446894, 0.23647295, 0.23847695,
#        0.24048096, 0.24248497, 0.24448898, 0.24649298, 0.248497  ,
#        0.250501  , 0.252505  , 0.25450903, 0.25651303, 0.25851703,
#        0.26052105, 0.26252505, 0.26452905, 0.26653308, 0.26853707,
#        0.27054107, 0.2725451 , 0.2745491 , 0.2765531 , 0.27855712,
#        0.28056112, 0.28256512, 0.28456914, 0.28657314, 0.28857717,
#        0.29058117, 0.29258516, 0.2945892 , 0.2965932 , 0.2985972 ,
#        0.3006012 , 0.3026052 , 0.3046092 , 0.30661324, 0.30861723,
#        0.31062123, 0.31262526, 0.31462926, 0.31663325, 0.31863728,
#        0.32064128, 0.32264528, 0.3246493 , 0.3266533 , 0.32865733,
#        0.33066133, 0.33266532, 0.33466935, 0.33667335, 0.33867735,
#        0.34068137, 0.34268537, 0.34468937, 0.3466934 , 0.3486974 ,
#        0.3507014 , 0.35270542, 0.35470942, 0.3567134 , 0.35871744,
#        0.36072144, 0.36272544, 0.36472946, 0.36673346, 0.3687375 ,
#        0.3707415 , 0.37274548, 0.3747495 , 0.3767535 , 0.3787575 ,
#        0.38076153, 0.38276553, 0.38476953, 0.38677356, 0.38877755,
#        0.39078155, 0.39278558, 0.39478958, 0.39679357, 0.3987976 ,
#        0.4008016 , 0.4028056 , 0.40480962, 0.40681362, 0.40881765,
#        0.41082165, 0.41282564, 0.41482967, 0.41683367, 0.41883767,
#        0.4208417 , 0.4228457 , 0.4248497 , 0.42685372, 0.4288577 ,
#        0.4308617 , 0.43286574, 0.43486974, 0.43687373, 0.43887776,
#        0.44088176, 0.4428858 , 0.44488978, 0.44689378, 0.4488978 ,
#        0.4509018 , 0.4529058 , 0.45490983, 0.45691383, 0.45891783,
#        0.46092185, 0.46292585, 0.46492985, 0.46693388, 0.46893787,
#        0.47094187, 0.4729459 , 0.4749499 , 0.4769539 , 0.47895792,
#        0.48096192, 0.48296595, 0.48496994, 0.48697394, 0.48897797,
#        0.49098197, 0.49298596, 0.49499   , 0.496994  , 0.498998  ,
#        0.501002  , 0.50300604, 0.50501   , 0.50701404, 0.50901806,
#        0.51102203, 0.51302606, 0.5150301 , 0.51703405, 0.5190381 ,
#        0.5210421 , 0.5230461 , 0.5250501 , 0.52705413, 0.5290581 ,
#        0.5310621 , 0.53306615, 0.5350701 , 0.53707415, 0.5390782 ,
#        0.54108214, 0.5430862 , 0.5450902 , 0.54709417, 0.5490982 ,
#        0.5511022 , 0.5531062 , 0.5551102 , 0.55711424, 0.5591182 ,
#        0.56112224, 0.56312627, 0.56513023, 0.56713426, 0.5691383 ,
#        0.57114226, 0.5731463 , 0.5751503 , 0.57715434, 0.5791583 ,
#        0.58116233, 0.58316636, 0.5851703 , 0.58717436, 0.5891784 ,
#        0.59118235, 0.5931864 , 0.5951904 , 0.5971944 , 0.5991984 ,
#        0.6012024 , 0.6032064 , 0.6052104 , 0.60721445, 0.6092184 ,
#        0.61122245, 0.6132265 , 0.61523044, 0.61723447, 0.6192385 ,
#        0.62124246, 0.6232465 , 0.6252505 , 0.6272545 , 0.6292585 ,
#        0.63126254, 0.6332665 , 0.63527054, 0.63727456, 0.63927853,
#        0.64128256, 0.6432866 , 0.64529055, 0.6472946 , 0.6492986 ,
#        0.6513026 , 0.6533066 , 0.65531063, 0.65731466, 0.6593186 ,
#        0.66132265, 0.6633267 , 0.66533065, 0.6673347 , 0.6693387 ,
#        0.6713427 , 0.6733467 , 0.6753507 , 0.6773547 , 0.6793587 ,
#        0.68136275, 0.6833667 , 0.68537074, 0.6873748 , 0.68937874,
#        0.69138277, 0.6933868 , 0.69539076, 0.6973948 , 0.6993988 ,
#        0.7014028 , 0.7034068 , 0.70541084, 0.7074148 , 0.70941883,
#        0.71142286, 0.7134268 , 0.71543086, 0.7174349 , 0.71943885,
#        0.7214429 , 0.7234469 , 0.7254509 , 0.7274549 , 0.7294589 ,
#        0.73146296, 0.7334669 , 0.73547095, 0.737475  , 0.73947895,
#        0.741483  , 0.743487  , 0.74549097, 0.747495  , 0.749499  ,
#        0.751503  , 0.753507  , 0.75551105, 0.757515  , 0.75951904,
#        0.76152307, 0.76352704, 0.76553106, 0.7675351 , 0.76953906,
#        0.7715431 , 0.7735471 , 0.7755511 , 0.7775551 , 0.77955914,
#        0.7815631 , 0.78356713, 0.78557116, 0.7875751 , 0.78957915,
#        0.7915832 , 0.79358715, 0.7955912 , 0.7975952 , 0.7995992 ,
#        0.8016032 , 0.8036072 , 0.8056112 , 0.8076152 , 0.80961925,
#        0.8116233 , 0.81362724, 0.8156313 , 0.8176353 , 0.81963927,
#        0.8216433 , 0.8236473 , 0.8256513 , 0.8276553 , 0.82965934,
#        0.8316633 , 0.83366734, 0.83567137, 0.83767533, 0.83967936,
#        0.8416834 , 0.84368736, 0.8456914 , 0.8476954 , 0.8496994 ,
#        0.8517034 , 0.85370743, 0.8557114 , 0.8577154 , 0.85971946,
#        0.8617234 , 0.86372745, 0.8657315 , 0.86773545, 0.8697395 ,
#        0.8717435 , 0.87374747, 0.8757515 , 0.8777555 , 0.8797595 ,
#        0.8817635 , 0.88376755, 0.8857716 , 0.88777554, 0.88977957,
#        0.8917836 , 0.89378756, 0.8957916 , 0.8977956 , 0.8997996 ,
#        0.9018036 , 0.90380764, 0.9058116 , 0.90781564, 0.90981966,
#        0.91182363, 0.91382766, 0.9158317 , 0.91783565, 0.9198397 ,
#        0.9218437 , 0.9238477 , 0.9258517 , 0.92785573, 0.9298597 ,
#        0.9318637 , 0.93386775, 0.9358717 , 0.93787575, 0.9398798 ,
#        0.94188374, 0.94388777, 0.9458918 , 0.94789577, 0.9498998 ,
#        0.9519038 , 0.9539078 , 0.9559118 , 0.95791584, 0.9599198 ,
#        0.96192384, 0.96392787, 0.9659319 , 0.96793586, 0.9699399 ,
#        0.9719439 , 0.9739479 , 0.9759519 , 0.97795594, 0.9799599 ,
#        0.98196393, 0.98396796, 0.9859719 , 0.98797596, 0.98998   ,
#        0.99198395, 0.993988  , 0.995992  , 0.997996  , 1.        ],
#       dtype=float32)

# %%
fig, ax = plt.subplots(figsize=(15, 8))

sns.set_theme(style='darkgrid')

x = np.linspace(0, 1, 500)
x = np.ascontiguousarray(x, dtype=np.float32)
EV = ((x * 90.91) - ((1 - x) * 100))
break_even = 0 * x


plt.plot(x, EV)
plt.plot(break_even)
plt.scatter(.5238, 0, color = 'black', linewidths=10)
ax.annotate('Break Even Point (52.4%)', fontsize=15, xy=(.53, 0), xytext=(.65, 5),arrowprops = {'facecolor':'black'})



plt.xlabel('Percentage of Bets Won', fontsize=15)
plt.ylabel('Expected Value Per $100 Bet', fontsize=15)
plt.xlim(0, 1);

# %%
even = np.random.choice([0, 1], size=1000, p=[.5, .5])
fiftyfive = np.random.choice([0, 1], size=1000, p=[.45, .55])
fiftythree = np.random.choice([0, 1], size=1000, p=[.47, .53])

# %%
profit = 0
profit_track = []
listn = []
for n in range(0, len(even)):
    listn.append(n)
    bet = ((even[n] * 90.91) - ((1 - even[n]) * 100))
    profit += bet
    profit_track.append(profit)

profitdf = pd.DataFrame(profit_track, listn, columns = ['profit'])

# %%
profitdf
# Out:
#      profit
# 0     90.91
# 1    181.82
# 2    272.73
# 3    363.64
# 4    454.55
# ..      ...
# 195 -127.18
# 196  -36.27
# 197   54.64
# 198  -45.36
# 199 -145.36
#
# [200 rows x 1 columns]

# %%
profit2 = 0
profit_track2 = []
listn2 = []
for n in range(0, len(fiftyfive)):
    listn2.append(n)
    bet = ((fiftyfive[n] * 90.91) - ((1 - fiftyfive[n]) * 100))
    profit2 += bet
    profit_track2.append(profit2)

profitdf2 = pd.DataFrame(profit_track2, listn2, columns = ['profit'])

# %%
profit3 = 0
profit_track3 = []
listn3 = []
for n in range(0, len(fiftythree)):
    listn3.append(n)
    bet = ((fiftythree[n] * 90.91) - ((1 - fiftythree[n]) * 100))
    profit3 += bet
    profit_track3.append(profit3)

profitdf3 = pd.DataFrame(profit_track3, listn3, columns = ['profit'])

# %%
profitdf3
# Out:
#       profit
# 0      90.91
# 1      -9.09
# 2    -109.09
# 3    -209.09
# 4    -118.18
# ..       ...
# 195 -1081.73
# 196 -1181.73
# 197 -1281.73
# 198 -1190.82
# 199 -1099.91
#
# [200 rows x 1 columns]

# %%
fig, ax = plt.subplots(figsize=(15,10))

plt.plot(profitdf2.index, profitdf2.profit, color='Green', label = '55% Correct')
plt.plot(profitdf3.index, profitdf3.profit, 'Blue', label = '53% correct')
plt.plot(profitdf.index, profitdf.profit, color='Red', label='50% correct')

plt.legend()
plt.xlabel('Number of Bets Placed')
plt.ylabel('Profit')
;
# Out:
# ''

# %%
import pickle

# %%
with open('data/pickles/testdf21.p', 'rb') as readfile: 
    testdf21 = pickle.load(readfile)

# %%
with open('data/pickles/model_df21.p', 'rb') as readfile: 
    model_df21 = pickle.load(readfile)

# %%
model_df21
# Out:
#          TEAM_ID                   Team     GAME_ID   GAME_DATE      MATCHUP  \
# 0     1610612744  Golden State Warriors  0022000001  2020-12-22    GSW @ BKN
# 1     1610612751          Brooklyn Nets  0022000001  2020-12-22  BKN vs. GSW
# 2     1610612747     Los Angeles Lakers  0022000002  2020-12-22  LAL vs. LAC
# 3     1610612746            LA Clippers  0022000002  2020-12-22    LAC @ LAL
# 4     1610612749        Milwaukee Bucks  0022000003  2020-12-23    MIL @ BOS
# ...          ...                    ...         ...         ...          ...
# 2155  1610612759      San Antonio Spurs  0022001078  2021-05-16  SAS vs. PHX
# 2156  1610612761        Toronto Raptors  0022001079  2021-05-16  TOR vs. IND
# 2157  1610612754         Indiana Pacers  0022001079  2021-05-16    IND @ TOR
# 2158  1610612764     Washington Wizards  0022001080  2021-05-16  WAS vs. CHA
# 2159  1610612766      Charlotte Hornets  0022001080  2021-05-16    CHA @ WAS
#
#       Over/Under  Spread   ML WL Spread_Result  PTS  PLUS_MINUS  WIN  LOSS  \
# 0          234.5     7.5  265  L          Loss   99       -26.0    0     1
# 1          234.5    -7.5 -320  W           Win  125        26.0    1     0
# 2          219.0    -2.0 -135  L          Loss  109        -7.0    0     1
# 3          219.0     2.0  115  W           Win  116         7.0    1     0
# 4          223.0    -4.5 -190  L          Loss  121        -1.0    0     1
# ...          ...     ...  ... ..           ...  ...         ...  ...   ...
# 2155       220.0     2.0  110  L          Push  121        -2.0    0     1
# 2156       226.5     6.0  200  L          Loss  113       -12.0    0     1
# 2157       226.5    -6.0 -240  W           Win  125        12.0    1     0
# 2158       230.5    -7.0 -275  W          Loss  115         5.0    1     0
# 2159       230.5     7.0  235  L           Win  110        -5.0    0     1
#
#       WINS_SEASON  LOSS_SEASON     WIN_% previous_day  back_to_back  FG_PCT  \
# 0             NaN          NaN       NaN   2020-12-21             0   0.374
# 1             NaN          NaN       NaN   2020-12-21             0   0.457
# 2             NaN          NaN       NaN   2020-12-21             0   0.469
# 3             NaN          NaN       NaN   2020-12-21             0   0.473
# 4             NaN          NaN       NaN   2020-12-22             0   0.511
# ...           ...          ...       ...          ...           ...     ...
# 2155         33.0         38.0  0.338684   2021-05-15             1   0.510
# 2156         27.0         44.0  0.276136   2021-05-15             0   0.402
# 2157         33.0         38.0  0.338684   2021-05-15             1   0.505
# 2158         33.0         38.0  0.338684   2021-05-15             0   0.484
# 2159         33.0         38.0  0.338684   2021-05-15             1   0.394
#
#       FG3_PCT  FT_PCT  EFG_PCT_y  FTA_RATE  TM_TOV_PCT_y  OREB_PCT_y  \
# 0       0.303   0.652      0.424     0.232         0.158       0.203
# 1       0.429   0.813      0.538     0.348         0.177       0.241
# 2       0.310   0.774      0.525     0.383         0.180       0.182
# 3       0.350   0.737      0.548     0.204         0.150       0.212
# 4       0.400   0.833      0.589     0.200         0.155       0.244
# ...       ...     ...        ...       ...           ...         ...
# 2155    0.292   0.737      0.546     0.194         0.095       0.216
# 2156    0.316   0.793      0.464     0.299         0.113       0.271
# 2157    0.405   0.778      0.584     0.189         0.123       0.208
# 2158    0.323   0.810      0.538     0.231         0.134       0.208
# 2159    0.311   0.917      0.468     0.255         0.121       0.169
#
#       OPP_EFG_PCT  OPP_FTA_RATE  OPP_TOV_PCT  OPP_OREB_PCT    PIE  OFF_RATING  \
# 0           0.538         0.348        0.177         0.315  0.350        88.4
# 1           0.424         0.232        0.158         0.281  0.650       111.6
# 2           0.548         0.204        0.150         0.269  0.509       104.8
# 3           0.525         0.383        0.180         0.250  0.491       111.5
# 4           0.564         0.109        0.068         0.236  0.506       119.8
# ...           ...           ...          ...           ...    ...         ...
# 2155        0.572         0.038        0.077         0.255  0.479       117.5
# 2156        0.584         0.189        0.123         0.271  0.428       107.6
# 2157        0.464         0.299        0.113         0.322  0.572       117.9
# 2158        0.468         0.255        0.121         0.254  0.525       112.7
# 2159        0.538         0.231        0.134         0.271  0.475       105.8
#
#       DEF_RATING  NET_RATING  TS_PCT   PACE  AST_TOV  HOME_TEAM  PTS_ALLOWED  \
# 0          111.6       -23.2   0.454  112.0     1.44          0        125.0
# 1           88.4        23.2   0.589  112.0     1.20          1         99.0
# 2          111.5        -6.7   0.576  104.0     1.16          1        116.0
# 3          104.8         6.7   0.572  104.0     1.38          0        109.0
# 4          122.0        -2.2   0.618  100.5     1.19          0        122.0
# ...          ...         ...     ...    ...      ...        ...          ...
# 2155       118.3        -0.8   0.569  103.5     3.00          1        123.0
# 2156       117.9       -10.3   0.515  105.5     1.75          1        125.0
# 2157       107.6        10.3   0.607  105.5     2.62          0        113.0
# 2158       105.8         7.0   0.574  103.0     1.57          1        110.0
# 2159       112.7        -7.0   0.526  103.0     1.92          0        115.0
#
#       PTS LAST 5  PLUS_MINUS LAST 5  FG_PCT LAST 5  FG3_PCT LAST 5  \
# 0            NaN                NaN            NaN             NaN
# 1            NaN                NaN            NaN             NaN
# 2            NaN                NaN            NaN             NaN
# 3            NaN                NaN            NaN             NaN
# 4            NaN                NaN            NaN             NaN
# ...          ...                ...            ...             ...
# 2155       113.0              -10.8         0.4562          0.3102
# 2156       107.2               -9.4         0.4352          0.3252
# 2157       118.8                0.2         0.4798          0.3500
# 2158       124.8                2.6         0.4596          0.3678
# 2159       108.6               -5.8         0.4346          0.2888
#
#       FT_PCT LAST 5  EFG_PCT_y LAST 5  FTA_RATE LAST 5  TM_TOV_PCT_y LAST 5  \
# 0               NaN               NaN              NaN                  NaN
# 1               NaN               NaN              NaN                  NaN
# 2               NaN               NaN              NaN                  NaN
# 3               NaN               NaN              NaN                  NaN
# 4               NaN               NaN              NaN                  NaN
# ...             ...               ...              ...                  ...
# 2155         0.8424            0.5018           0.2438               0.1046
# 2156         0.7298            0.4994           0.2266               0.1182
# 2157         0.8116            0.5448           0.2024               0.1126
# 2158         0.8404            0.5122           0.2888               0.1052
# 2159         0.7738            0.4940           0.2482               0.1290
#
#       OREB_PCT_y LAST 5  OPP_EFG_PCT LAST 5  OPP_FTA_RATE LAST 5  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
# ...                 ...                 ...                  ...
# 2155             0.1824              0.5800               0.2678
# 2156             0.1782              0.5556               0.2898
# 2157             0.1734              0.5136               0.3012
# 2158             0.1958              0.5306               0.2784
# 2159             0.2202              0.5684               0.2422
#
#       OPP_TOV_PCT LAST 5  OPP_OREB_PCT LAST 5  PIE LAST 5  OFF_RATING LAST 5  \
# 0                    NaN                  NaN         NaN                NaN
# 1                    NaN                  NaN         NaN                NaN
# 2                    NaN                  NaN         NaN                NaN
# 3                    NaN                  NaN         NaN                NaN
# 4                    NaN                  NaN         NaN                NaN
# ...                  ...                  ...         ...                ...
# 2155              0.0936               0.2212      0.4296             111.62
# 2156              0.1554               0.2998      0.4336             106.30
# 2157              0.1208               0.3050      0.5174             113.60
# 2158              0.1266               0.2516      0.5108             114.48
# 2159              0.1344               0.2484      0.4712             107.96
#
#       DEF_RATING LAST 5  NET_RATING LAST 5  TS_PCT LAST 5  PACE LAST 5  \
# 0                   NaN                NaN            NaN          NaN
# 1                   NaN                NaN            NaN          NaN
# 2                   NaN                NaN            NaN          NaN
# 3                   NaN                NaN            NaN          NaN
# 4                   NaN                NaN            NaN          NaN
# ...                 ...                ...            ...          ...
# 2155             122.32             -10.74         0.5464      101.100
# 2156             115.64              -9.34         0.5300       98.616
# 2157             113.28               0.36         0.5760      102.198
# 2158             111.46               3.02         0.5622      105.014
# 2159             114.28              -6.32         0.5310       98.432
#
#       AST_TOV LAST 5  PTS_ALLOWED LAST 5  PTS LAST 10  PLUS_MINUS LAST 10  \
# 0                NaN                 NaN          NaN                 NaN
# 1                NaN                 NaN          NaN                 NaN
# 2                NaN                 NaN          NaN                 NaN
# 3                NaN                 NaN          NaN                 NaN
# 4                NaN                 NaN          NaN                 NaN
# ...              ...                 ...          ...                 ...
# 2155           2.116               123.8        112.2                -9.3
# 2156           1.730               116.6        107.3                -7.2
# 2157           2.770               118.6        122.6                 2.4
# 2158           2.542               122.2        127.4                 6.2
# 2159           2.194               114.4        107.3                -5.3
#
#       FG_PCT LAST 10  FG3_PCT LAST 10  FT_PCT LAST 10  EFG_PCT_y LAST 10  \
# 0                NaN              NaN             NaN                NaN
# 1                NaN              NaN             NaN                NaN
# 2                NaN              NaN             NaN                NaN
# 3                NaN              NaN             NaN                NaN
# 4                NaN              NaN             NaN                NaN
# ...              ...              ...             ...                ...
# 2155          0.4648           0.3160          0.8338             0.5084
# 2156          0.4408           0.3577          0.7316             0.5120
# 2157          0.5031           0.3947          0.8224             0.5700
# 2158          0.4938           0.3705          0.8120             0.5395
# 2159          0.4406           0.3332          0.6981             0.5076
#
#       FTA_RATE LAST 10  TM_TOV_PCT_y LAST 10  OREB_PCT_y LAST 10  \
# 0                  NaN                   NaN                 NaN
# 1                  NaN                   NaN                 NaN
# 2                  NaN                   NaN                 NaN
# 3                  NaN                   NaN                 NaN
# 4                  NaN                   NaN                 NaN
# ...                ...                   ...                 ...
# 2155            0.2350                0.1079              0.1745
# 2156            0.2134                0.1232              0.1888
# 2157            0.2141                0.1305              0.1648
# 2158            0.2982                0.1105              0.2144
# 2159            0.2569                0.1288              0.2262
#
#       OPP_EFG_PCT LAST 10  OPP_FTA_RATE LAST 10  OPP_TOV_PCT LAST 10  \
# 0                     NaN                   NaN                  NaN
# 1                     NaN                   NaN                  NaN
# 2                     NaN                   NaN                  NaN
# 3                     NaN                   NaN                  NaN
# 4                     NaN                   NaN                  NaN
# ...                   ...                   ...                  ...
# 2155               0.5744                0.2468               0.1195
# 2156               0.5656                0.2715               0.1538
# 2157               0.5282                0.2599               0.1231
# 2158               0.5439                0.2754               0.1397
# 2159               0.5548                0.2366               0.1361
#
#       OPP_OREB_PCT LAST 10  PIE LAST 10  OFF_RATING LAST 10  \
# 0                      NaN          NaN                 NaN
# 1                      NaN          NaN                 NaN
# 2                      NaN          NaN                 NaN
# 3                      NaN          NaN                 NaN
# 4                      NaN          NaN                 NaN
# ...                    ...          ...                 ...
# 2155                0.2593       0.4518              110.18
# 2156                0.2679       0.4483              108.01
# 2157                0.2909       0.5196              115.35
# 2158                0.2672       0.5347              118.22
# 2159                0.2917       0.4784              109.11
#
#       DEF_RATING LAST 10  NET_RATING LAST 10  TS_PCT LAST 10  PACE LAST 10  \
# 0                    NaN                 NaN             NaN           NaN
# 1                    NaN                 NaN             NaN           NaN
# 2                    NaN                 NaN             NaN           NaN
# 3                    NaN                 NaN             NaN           NaN
# 4                    NaN                 NaN             NaN           NaN
# ...                  ...                 ...             ...           ...
# 2155              119.04               -8.88          0.5482        99.727
# 2156              115.17               -7.17          0.5400        98.258
# 2157              113.16                2.21          0.6011       104.899
# 2158              112.23                5.99          0.5839       105.657
# 2159              114.41               -5.30          0.5372        97.416
#
#       AST_TOV LAST 10  PTS_ALLOWED LAST 10  PTS Season  PLUS_MINUS Season  \
# 0                 NaN                  NaN         NaN                NaN
# 1                 NaN                  NaN         NaN                NaN
# 2                 NaN                  NaN         NaN                NaN
# 3                 NaN                  NaN         NaN                NaN
# 4                 NaN                  NaN         NaN                NaN
# ...               ...                  ...         ...                ...
# 2155            2.125                121.5  110.943662          -1.732394
# 2156            1.847                114.5  111.239437          -0.309859
# 2157            2.372                120.2  115.169014          -0.211268
# 2158            2.516                121.2  116.661972          -1.929577
# 2159            2.213                112.6  109.450704          -1.887324
#
#       FG_PCT Season  FG3_PCT Season  FT_PCT Season  EFG_PCT_y Season  \
# 0               NaN             NaN            NaN               NaN
# 1               NaN             NaN            NaN               NaN
# 2               NaN             NaN            NaN               NaN
# 3               NaN             NaN            NaN               NaN
# 4               NaN             NaN            NaN               NaN
# ...             ...             ...            ...               ...
# 2155       0.462028        0.347549       0.793887          0.517394
# 2156       0.449704        0.368338       0.813352          0.531901
# 2157       0.474986        0.364127       0.790831          0.542704
# 2158       0.474380        0.353563       0.770183          0.530493
# 2159       0.456254        0.368775       0.752493          0.534606
#
#       FTA_RATE Season  TM_TOV_PCT_y Season  OREB_PCT_y Season  \
# 0                 NaN                  NaN                NaN
# 1                 NaN                  NaN                NaN
# 2                 NaN                  NaN                NaN
# 3                 NaN                  NaN                NaN
# 4                 NaN                  NaN                NaN
# ...               ...                  ...                ...
# 2155         0.245183             0.111930           0.181113
# 2156         0.240972             0.130127           0.181704
# 2157         0.229634             0.129254           0.178507
# 2158         0.290507             0.134423           0.190014
# 2159         0.238803             0.146606           0.208056
#
#       OPP_EFG_PCT Season  OPP_FTA_RATE Season  OPP_TOV_PCT Season  \
# 0                    NaN                  NaN                 NaN
# 1                    NaN                  NaN                 NaN
# 2                    NaN                  NaN                 NaN
# 3                    NaN                  NaN                 NaN
# 4                    NaN                  NaN                 NaN
# ...                  ...                  ...                 ...
# 2155            0.540577             0.234859            0.130113
# 2156            0.544282             0.297676            0.158845
# 2157            0.533211             0.261028            0.141099
# 2158            0.539915             0.279972            0.136775
# 2159            0.552437             0.219789            0.146014
#
#       OPP_OREB_PCT Season  PIE Season  OFF_RATING Season  DEF_RATING Season  \
# 0                     NaN         NaN                NaN                NaN
# 1                     NaN         NaN                NaN                NaN
# 2                     NaN         NaN                NaN                NaN
# 3                     NaN         NaN                NaN                NaN
# 4                     NaN         NaN                NaN                NaN
# ...                   ...         ...                ...                ...
# 2155             0.264085    0.495958         110.361972         111.842254
# 2156             0.282296    0.486352         111.692958         111.938028
# 2157             0.294479    0.500662         111.778873         111.819718
# 2158             0.262831    0.495887         110.647887         112.456338
# 2159             0.275141    0.490310         110.123944         112.077465
#
#       NET_RATING Season  TS_PCT Season  PACE Season  AST_TOV Season  \
# 0                   NaN            NaN          NaN             NaN
# 1                   NaN            NaN          NaN             NaN
# 2                   NaN            NaN          NaN             NaN
# 3                   NaN            NaN          NaN             NaN
# 4                   NaN            NaN          NaN             NaN
# ...                 ...            ...          ...             ...
# 2155          -1.477465       0.554493    99.425070        2.354085
# 2156          -0.246479       0.569746    99.487042        1.930141
# 2157          -0.036620       0.575155   102.019437        2.176620
# 2158          -1.801408       0.569197   104.698310        1.963099
# 2159          -1.952113       0.565732    98.975775        1.988169
#
#       PTS_ALLOWED Season    PTS Home  PLUS_MINUS Home  FG_PCT Home  \
# 0                    NaN         NaN              NaN          NaN
# 1                    NaN         NaN              NaN          NaN
# 2                    NaN         NaN              NaN          NaN
# 3                    NaN         NaN              NaN          NaN
# 4                    NaN         NaN              NaN          NaN
# ...                  ...         ...              ...          ...
# 2155          112.676056  109.971429        -3.342857     0.461600
# 2156          111.549296  111.028571         1.885714     0.445971
# 2157          115.380282         NaN              NaN          NaN
# 2158          118.591549  119.114286        -0.228571     0.481914
# 2159          111.338028         NaN              NaN          NaN
#
#       FG3_PCT Home  FT_PCT Home  EFG_PCT_y Home  FTA_RATE Home  \
# 0              NaN          NaN             NaN            NaN
# 1              NaN          NaN             NaN            NaN
# 2              NaN          NaN             NaN            NaN
# 3              NaN          NaN             NaN            NaN
# 4              NaN          NaN             NaN            NaN
# ...            ...          ...             ...            ...
# 2155      0.357657     0.782114        0.519571       0.239086
# 2156      0.355943     0.828571        0.525857       0.241171
# 2157           NaN          NaN             NaN            NaN
# 2158      0.347286     0.763629        0.537771       0.295171
# 2159           NaN          NaN             NaN            NaN
#
#       TM_TOV_PCT_y Home  OREB_PCT_y Home  OPP_EFG_PCT Home  OPP_FTA_RATE Home  \
# 0                   NaN              NaN               NaN                NaN
# 1                   NaN              NaN               NaN                NaN
# 2                   NaN              NaN               NaN                NaN
# 3                   NaN              NaN               NaN                NaN
# 4                   NaN              NaN               NaN                NaN
# ...                 ...              ...               ...                ...
# 2155           0.117029         0.179886          0.546771           0.226114
# 2156           0.133743         0.193743          0.530000           0.283229
# 2157                NaN              NaN               NaN                NaN
# 2158           0.130457         0.187657          0.534971           0.290457
# 2159                NaN              NaN               NaN                NaN
#
#       OPP_TOV_PCT Home  OPP_OREB_PCT Home  PIE Home  OFF_RATING Home  \
# 0                  NaN                NaN       NaN              NaN
# 1                  NaN                NaN       NaN              NaN
# 2                  NaN                NaN       NaN              NaN
# 3                  NaN                NaN       NaN              NaN
# 4                  NaN                NaN       NaN              NaN
# ...                ...                ...       ...              ...
# 2155          0.127886           0.250257  0.489714       109.577143
# 2156          0.157171           0.279543  0.498714       111.657143
# 2157               NaN                NaN       NaN              NaN
# 2158          0.135000           0.258486  0.501514       112.037143
# 2159               NaN                NaN       NaN              NaN
#
#       DEF_RATING Home  NET_RATING Home  TS_PCT Home   PACE Home  AST_TOV Home  \
# 0                 NaN              NaN          NaN         NaN           NaN
# 1                 NaN              NaN          NaN         NaN           NaN
# 2                 NaN              NaN          NaN         NaN           NaN
# 3                 NaN              NaN          NaN         NaN           NaN
# 4                 NaN              NaN          NaN         NaN           NaN
# ...               ...              ...          ...         ...           ...
# 2155       112.514286        -2.928571     0.553886   99.046571      2.241714
# 2156       109.768571         1.894286     0.566057   99.145143      1.808286
# 2157              NaN              NaN          NaN         NaN           NaN
# 2158       112.217143        -0.180000     0.575257  105.738857      1.977714
# 2159              NaN              NaN          NaN         NaN           NaN
#
#       PTS_ALLOWED Home    PTS Away  PLUS_MINUS Away  FG_PCT Away  \
# 0                  NaN         NaN              NaN          NaN
# 1                  NaN         NaN              NaN          NaN
# 2                  NaN         NaN              NaN          NaN
# 3                  NaN         NaN              NaN          NaN
# 4                  NaN         NaN              NaN          NaN
# ...                ...         ...              ...          ...
# 2155        113.314286         NaN              NaN          NaN
# 2156        109.142857         NaN              NaN          NaN
# 2157               NaN  117.571429         2.400000     0.482600
# 2158        119.342857         NaN              NaN          NaN
# 2159               NaN  110.542857        -3.714286     0.456486
#
#       FG3_PCT Away  FT_PCT Away  EFG_PCT_y Away  FTA_RATE Away  \
# 0              NaN          NaN             NaN            NaN
# 1              NaN          NaN             NaN            NaN
# 2              NaN          NaN             NaN            NaN
# 3              NaN          NaN             NaN            NaN
# 4              NaN          NaN             NaN            NaN
# ...            ...          ...             ...            ...
# 2155           NaN          NaN             NaN            NaN
# 2156           NaN          NaN             NaN            NaN
# 2157      0.381029     0.807229        0.553686       0.212629
# 2158           NaN          NaN             NaN            NaN
# 2159      0.369200     0.754400        0.534029       0.257000
#
#       TM_TOV_PCT_y Away  OREB_PCT_y Away  OPP_EFG_PCT Away  OPP_FTA_RATE Away  \
# 0                   NaN              NaN               NaN                NaN
# 1                   NaN              NaN               NaN                NaN
# 2                   NaN              NaN               NaN                NaN
# 3                   NaN              NaN               NaN                NaN
# 4                   NaN              NaN               NaN                NaN
# ...                 ...              ...               ...                ...
# 2155                NaN              NaN               NaN                NaN
# 2156                NaN              NaN               NaN                NaN
# 2157           0.129571         0.188771          0.527029           0.245371
# 2158                NaN              NaN               NaN                NaN
# 2159           0.146600         0.210371          0.571143           0.214114
#
#       OPP_TOV_PCT Away  OPP_OREB_PCT Away  PIE Away  OFF_RATING Away  \
# 0                  NaN                NaN       NaN              NaN
# 1                  NaN                NaN       NaN              NaN
# 2                  NaN                NaN       NaN              NaN
# 3                  NaN                NaN       NaN              NaN
# 4                  NaN                NaN       NaN              NaN
# ...                ...                ...       ...              ...
# 2155               NaN                NaN       NaN              NaN
# 2156               NaN                NaN       NaN              NaN
# 2157          0.142800           0.300229  0.521286       113.648571
# 2158               NaN                NaN       NaN              NaN
# 2159          0.152286           0.280543  0.482971       110.377143
#
#       DEF_RATING Away  NET_RATING Away  TS_PCT Away   PACE Away  AST_TOV Away  \
# 0                 NaN              NaN          NaN         NaN           NaN
# 1                 NaN              NaN          NaN         NaN           NaN
# 2                 NaN              NaN          NaN         NaN           NaN
# 3                 NaN              NaN          NaN         NaN           NaN
# 4                 NaN              NaN          NaN         NaN           NaN
# ...               ...              ...          ...         ...           ...
# 2155              NaN              NaN          NaN         NaN           NaN
# 2156              NaN              NaN          NaN         NaN           NaN
# 2157       111.088571         2.562857     0.584486  102.290000      2.247429
# 2158              NaN              NaN          NaN         NaN           NaN
# 2159       114.034286        -3.662857     0.568029   99.659143      1.919429
#
#       PTS_ALLOWED Away
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 2155               NaN
# 2156               NaN
# 2157        115.171429
# 2158               NaN
# 2159        114.257143
#
# [2160 rows x 144 columns]

# %%
list(testdf21.columns)
# Out:
# ['TEAM_ID_Home',
#  'Team_Home',
#  'GAME_ID',
#  'GAME_DATE',
#  'MATCHUP_Home',
#  'Over/Under',
#  'Spread_Home',
#  'ML_Home',
#  'WL_Home',
#  'Spread_Result_Home',
#  'PTS_Home',
#  'PLUS_MINUS_Home',
#  'WIN_Home',
#  'LOSS_Home',
#  'WINS_SEASON_Home',
#  'LOSS_SEASON_Home',
#  'WIN_%_Home',
#  'previous_day_Home',
#  'back_to_back_Home',
#  'FG_PCT_Home',
#  'FG3_PCT_Home',
#  'FT_PCT_Home',
#  'EFG_PCT_y_Home',
#  'FTA_RATE_Home',
#  'TM_TOV_PCT_y_Home',
#  'OREB_PCT_y_Home',
#  'OPP_EFG_PCT_Home',
#  'OPP_FTA_RATE_Home',
#  'OPP_TOV_PCT_Home',
#  'OPP_OREB_PCT_Home',
#  'PIE_Home',
#  'OFF_RATING_Home',
#  'DEF_RATING_Home',
#  'NET_RATING_Home',
#  'TS_PCT_Home',
#  'PACE_Home',
#  'AST_TOV_Home',
#  'HOME_TEAM_Home',
#  'PTS_ALLOWED_Home',
#  'PTS LAST 5_Home',
#  'PLUS_MINUS LAST 5_Home',
#  'FG_PCT LAST 5_Home',
#  'FG3_PCT LAST 5_Home',
#  'FT_PCT LAST 5_Home',
#  'EFG_PCT_y LAST 5_Home',
#  'FTA_RATE LAST 5_Home',
#  'TM_TOV_PCT_y LAST 5_Home',
#  'OREB_PCT_y LAST 5_Home',
#  'OPP_EFG_PCT LAST 5_Home',
#  'OPP_FTA_RATE LAST 5_Home',
#  'OPP_TOV_PCT LAST 5_Home',
#  'OPP_OREB_PCT LAST 5_Home',
#  'PIE LAST 5_Home',
#  'OFF_RATING LAST 5_Home',
#  'DEF_RATING LAST 5_Home',
#  'NET_RATING LAST 5_Home',
#  'TS_PCT LAST 5_Home',
#  'PACE LAST 5_Home',
#  'AST_TOV LAST 5_Home',
#  'PTS_ALLOWED LAST 5_Home',
#  'PTS LAST 10_Home',
#  'PLUS_MINUS LAST 10_Home',
#  'FG_PCT LAST 10_Home',
#  'FG3_PCT LAST 10_Home',
#  'FT_PCT LAST 10_Home',
#  'EFG_PCT_y LAST 10_Home',
#  'FTA_RATE LAST 10_Home',
#  'TM_TOV_PCT_y LAST 10_Home',
#  'OREB_PCT_y LAST 10_Home',
#  'OPP_EFG_PCT LAST 10_Home',
#  'OPP_FTA_RATE LAST 10_Home',
#  'OPP_TOV_PCT LAST 10_Home',
#  'OPP_OREB_PCT LAST 10_Home',
#  'PIE LAST 10_Home',
#  'OFF_RATING LAST 10_Home',
#  'DEF_RATING LAST 10_Home',
#  'NET_RATING LAST 10_Home',
#  'TS_PCT LAST 10_Home',
#  'PACE LAST 10_Home',
#  'AST_TOV LAST 10_Home',
#  'PTS_ALLOWED LAST 10_Home',
#  'PTS Season_Home',
#  'PLUS_MINUS Season_Home',
#  'FG_PCT Season_Home',
#  'FG3_PCT Season_Home',
#  'FT_PCT Season_Home',
#  'EFG_PCT_y Season_Home',
#  'FTA_RATE Season_Home',
#  'TM_TOV_PCT_y Season_Home',
#  'OREB_PCT_y Season_Home',
#  'OPP_EFG_PCT Season_Home',
#  'OPP_FTA_RATE Season_Home',
#  'OPP_TOV_PCT Season_Home',
#  'OPP_OREB_PCT Season_Home',
#  'PIE Season_Home',
#  'OFF_RATING Season_Home',
#  'DEF_RATING Season_Home',
#  'NET_RATING Season_Home',
#  'TS_PCT Season_Home',
#  'PACE Season_Home',
#  'AST_TOV Season_Home',
#  'PTS_ALLOWED Season_Home',
#  'PTS Home_Home',
#  'PLUS_MINUS Home_Home',
#  'FG_PCT Home_Home',
#  'FG3_PCT Home_Home',
#  'FT_PCT Home_Home',
#  'EFG_PCT_y Home_Home',
#  'FTA_RATE Home_Home',
#  'TM_TOV_PCT_y Home_Home',
#  'OREB_PCT_y Home_Home',
#  'OPP_EFG_PCT Home_Home',
#  'OPP_FTA_RATE Home_Home',
#  'OPP_TOV_PCT Home_Home',
#  'OPP_OREB_PCT Home_Home',
#  'PIE Home_Home',
#  'OFF_RATING Home_Home',
#  'DEF_RATING Home_Home',
#  'NET_RATING Home_Home',
#  'TS_PCT Home_Home',
#  'PACE Home_Home',
#  'AST_TOV Home_Home',
#  'PTS_ALLOWED Home_Home',
#  'TEAM_ID_Away',
#  'Team_Away',
#  'MATCHUP_Away',
#  'Over/Under_Away',
#  'Spread_Away',
#  'ML_Away',
#  'WL_Away',
#  'Spread_Result_Away',
#  'PTS_Away',
#  'PLUS_MINUS_Away',
#  'WIN_Away',
#  'LOSS_Away',
#  'WINS_SEASON_Away',
#  'LOSS_SEASON_Away',
#  'WIN_%_Away',
#  'previous_day_Away',
#  'back_to_back_Away',
#  'FG_PCT_Away',
#  'FG3_PCT_Away',
#  'FT_PCT_Away',
#  'EFG_PCT_y_Away',
#  'FTA_RATE_Away',
#  'TM_TOV_PCT_y_Away',
#  'OREB_PCT_y_Away',
#  'OPP_EFG_PCT_Away',
#  'OPP_FTA_RATE_Away',
#  'OPP_TOV_PCT_Away',
#  'OPP_OREB_PCT_Away',
#  'PIE_Away',
#  'OFF_RATING_Away',
#  'DEF_RATING_Away',
#  'NET_RATING_Away',
#  'TS_PCT_Away',
#  'PACE_Away',
#  'AST_TOV_Away',
#  'HOME_TEAM_Away',
#  'PTS_ALLOWED_Away',
#  'PTS LAST 5_Away',
#  'PLUS_MINUS LAST 5_Away',
#  'FG_PCT LAST 5_Away',
#  'FG3_PCT LAST 5_Away',
#  'FT_PCT LAST 5_Away',
#  'EFG_PCT_y LAST 5_Away',
#  'FTA_RATE LAST 5_Away',
#  'TM_TOV_PCT_y LAST 5_Away',
#  'OREB_PCT_y LAST 5_Away',
#  'OPP_EFG_PCT LAST 5_Away',
#  'OPP_FTA_RATE LAST 5_Away',
#  'OPP_TOV_PCT LAST 5_Away',
#  'OPP_OREB_PCT LAST 5_Away',
#  'PIE LAST 5_Away',
#  'OFF_RATING LAST 5_Away',
#  'DEF_RATING LAST 5_Away',
#  'NET_RATING LAST 5_Away',
#  'TS_PCT LAST 5_Away',
#  'PACE LAST 5_Away',
#  'AST_TOV LAST 5_Away',
#  'PTS_ALLOWED LAST 5_Away',
#  'PTS LAST 10_Away',
#  'PLUS_MINUS LAST 10_Away',
#  'FG_PCT LAST 10_Away',
#  'FG3_PCT LAST 10_Away',
#  'FT_PCT LAST 10_Away',
#  'EFG_PCT_y LAST 10_Away',
#  'FTA_RATE LAST 10_Away',
#  'TM_TOV_PCT_y LAST 10_Away',
#  'OREB_PCT_y LAST 10_Away',
#  'OPP_EFG_PCT LAST 10_Away',
#  'OPP_FTA_RATE LAST 10_Away',
#  'OPP_TOV_PCT LAST 10_Away',
#  'OPP_OREB_PCT LAST 10_Away',
#  'PIE LAST 10_Away',
#  'OFF_RATING LAST 10_Away',
#  'DEF_RATING LAST 10_Away',
#  'NET_RATING LAST 10_Away',
#  'TS_PCT LAST 10_Away',
#  'PACE LAST 10_Away',
#  'AST_TOV LAST 10_Away',
#  'PTS_ALLOWED LAST 10_Away',
#  'PTS Season_Away',
#  'PLUS_MINUS Season_Away',
#  'FG_PCT Season_Away',
#  'FG3_PCT Season_Away',
#  'FT_PCT Season_Away',
#  'EFG_PCT_y Season_Away',
#  'FTA_RATE Season_Away',
#  'TM_TOV_PCT_y Season_Away',
#  'OREB_PCT_y Season_Away',
#  'OPP_EFG_PCT Season_Away',
#  'OPP_FTA_RATE Season_Away',
#  'OPP_TOV_PCT Season_Away',
#  'OPP_OREB_PCT Season_Away',
#  'PIE Season_Away',
#  'OFF_RATING Season_Away',
#  'DEF_RATING Season_Away',
#  'NET_RATING Season_Away',
#  'TS_PCT Season_Away',
#  'PACE Season_Away',
#  'AST_TOV Season_Away',
#  'PTS_ALLOWED Season_Away',
#  'PTS Away_Away',
#  'PLUS_MINUS Away_Away',
#  'FG_PCT Away_Away',
#  'FG3_PCT Away_Away',
#  'FT_PCT Away_Away',
#  'EFG_PCT_y Away_Away',
#  'FTA_RATE Away_Away',
#  'TM_TOV_PCT_y Away_Away',
#  'OREB_PCT_y Away_Away',
#  'OPP_EFG_PCT Away_Away',
#  'OPP_FTA_RATE Away_Away',
#  'OPP_TOV_PCT Away_Away',
#  'OPP_OREB_PCT Away_Away',
#  'PIE Away_Away',
#  'OFF_RATING Away_Away',
#  'DEF_RATING Away_Away',
#  'NET_RATING Away_Away',
#  'TS_PCT Away_Away',
#  'PACE Away_Away',
#  'AST_TOV Away_Away',
#  'PTS_ALLOWED Away_Away',
#  'TOTAL_PTS',
#  'Over/Under Result']

# %%
list(model_df21.columns)
# Out:
# ['TEAM_ID',
#  'Team',
#  'GAME_ID',
#  'GAME_DATE',
#  'MATCHUP',
#  'Over/Under',
#  'Spread',
#  'ML',
#  'WL',
#  'Spread_Result',
#  'PTS',
#  'PLUS_MINUS',
#  'WIN',
#  'LOSS',
#  'WINS_SEASON',
#  'LOSS_SEASON',
#  'WIN_%',
#  'previous_day',
#  'back_to_back',
#  'FG_PCT',
#  'FG3_PCT',
#  'FT_PCT',
#  'EFG_PCT_y',
#  'FTA_RATE',
#  'TM_TOV_PCT_y',
#  'OREB_PCT_y',
#  'OPP_EFG_PCT',
#  'OPP_FTA_RATE',
#  'OPP_TOV_PCT',
#  'OPP_OREB_PCT',
#  'PIE',
#  'OFF_RATING',
#  'DEF_RATING',
#  'NET_RATING',
#  'TS_PCT',
#  'PACE',
#  'AST_TOV',
#  'HOME_TEAM',
#  'PTS_ALLOWED',
#  'PTS LAST 5',
#  'PLUS_MINUS LAST 5',
#  'FG_PCT LAST 5',
#  'FG3_PCT LAST 5',
#  'FT_PCT LAST 5',
#  'EFG_PCT_y LAST 5',
#  'FTA_RATE LAST 5',
#  'TM_TOV_PCT_y LAST 5',
#  'OREB_PCT_y LAST 5',
#  'OPP_EFG_PCT LAST 5',
#  'OPP_FTA_RATE LAST 5',
#  'OPP_TOV_PCT LAST 5',
#  'OPP_OREB_PCT LAST 5',
#  'PIE LAST 5',
#  'OFF_RATING LAST 5',
#  'DEF_RATING LAST 5',
#  'NET_RATING LAST 5',
#  'TS_PCT LAST 5',
#  'PACE LAST 5',
#  'AST_TOV LAST 5',
#  'PTS_ALLOWED LAST 5',
#  'PTS LAST 10',
#  'PLUS_MINUS LAST 10',
#  'FG_PCT LAST 10',
#  'FG3_PCT LAST 10',
#  'FT_PCT LAST 10',
#  'EFG_PCT_y LAST 10',
#  'FTA_RATE LAST 10',
#  'TM_TOV_PCT_y LAST 10',
#  'OREB_PCT_y LAST 10',
#  'OPP_EFG_PCT LAST 10',
#  'OPP_FTA_RATE LAST 10',
#  'OPP_TOV_PCT LAST 10',
#  'OPP_OREB_PCT LAST 10',
#  'PIE LAST 10',
#  'OFF_RATING LAST 10',
#  'DEF_RATING LAST 10',
#  'NET_RATING LAST 10',
#  'TS_PCT LAST 10',
#  'PACE LAST 10',
#  'AST_TOV LAST 10',
#  'PTS_ALLOWED LAST 10',
#  'PTS Season',
#  'PLUS_MINUS Season',
#  'FG_PCT Season',
#  'FG3_PCT Season',
#  'FT_PCT Season',
#  'EFG_PCT_y Season',
#  'FTA_RATE Season',
#  'TM_TOV_PCT_y Season',
#  'OREB_PCT_y Season',
#  'OPP_EFG_PCT Season',
#  'OPP_FTA_RATE Season',
#  'OPP_TOV_PCT Season',
#  'OPP_OREB_PCT Season',
#  'PIE Season',
#  'OFF_RATING Season',
#  'DEF_RATING Season',
#  'NET_RATING Season',
#  'TS_PCT Season',
#  'PACE Season',
#  'AST_TOV Season',
#  'PTS_ALLOWED Season',
#  'PTS Home',
#  'PLUS_MINUS Home',
#  'FG_PCT Home',
#  'FG3_PCT Home',
#  'FT_PCT Home',
#  'EFG_PCT_y Home',
#  'FTA_RATE Home',
#  'TM_TOV_PCT_y Home',
#  'OREB_PCT_y Home',
#  'OPP_EFG_PCT Home',
#  'OPP_FTA_RATE Home',
#  'OPP_TOV_PCT Home',
#  'OPP_OREB_PCT Home',
#  'PIE Home',
#  'OFF_RATING Home',
#  'DEF_RATING Home',
#  'NET_RATING Home',
#  'TS_PCT Home',
#  'PACE Home',
#  'AST_TOV Home',
#  'PTS_ALLOWED Home',
#  'PTS Away',
#  'PLUS_MINUS Away',
#  'FG_PCT Away',
#  'FG3_PCT Away',
#  'FT_PCT Away',
#  'EFG_PCT_y Away',
#  'FTA_RATE Away',
#  'TM_TOV_PCT_y Away',
#  'OREB_PCT_y Away',
#  'OPP_EFG_PCT Away',
#  'OPP_FTA_RATE Away',
#  'OPP_TOV_PCT Away',
#  'OPP_OREB_PCT Away',
#  'PIE Away',
#  'OFF_RATING Away',
#  'DEF_RATING Away',
#  'NET_RATING Away',
#  'TS_PCT Away',
#  'PACE Away',
#  'AST_TOV Away',
#  'PTS_ALLOWED Away']

# %%
b2bs = model_df21.loc[model_df21['back_to_back'] == 1]
rest = model_df21.loc[model_df21['back_to_back'] == 0]
winners = model_df21.loc[model_df21['WIN'] == 1]
losers = model_df21.loc[model_df21['WIN'] == 0]
home = model_df21.loc[model_df21['HOME_TEAM'] == 1]
away = model_df21.loc[model_df21['HOME_TEAM'] == 0]

# %%
b2bs[just_game].mean()
# Out:
# TEAM_ID         1.610613e+09
# GAME_ID                  inf
# Over/Under      2.233939e+02
# Spread          1.435449e+00
# ML              2.292123e+01
# PTS             1.112823e+02
# PLUS_MINUS     -7.763676e-01
# WIN             4.726477e-01
# LOSS            5.273523e-01
# WINS_SEASON     1.923851e+01
# LOSS_SEASON     1.954923e+01
# WIN_%                    inf
# back_to_back    1.000000e+00
# FG_PCT          4.651641e-01
# FG3_PCT         3.622582e-01
# FT_PCT          7.853545e-01
# EFG_PCT_y       5.360700e-01
# FTA_RATE        2.463260e-01
# TM_TOV_PCT_y    1.330832e-01
# OREB_PCT_y      1.942341e-01
# OPP_EFG_PCT     5.417462e-01
# OPP_FTA_RATE    2.511379e-01
# OPP_TOV_PCT     1.325317e-01
# OPP_OREB_PCT    2.599628e-01
# PIE             4.943895e-01
# OFF_RATING      1.114696e+02
# DEF_RATING      1.121818e+02
# NET_RATING     -7.161926e-01
# TS_PCT          5.702101e-01
# PACE            9.939755e+01
# AST_TOV         1.985252e+00
# HOME_TEAM       4.792123e-01
# PTS_ALLOWED     1.120586e+02
# dtype: float64

# %%
model_df21[just_game].mean()
# Out:
# TEAM_ID         1.610613e+09
# GAME_ID                  inf
# Over/Under      2.241255e+02
# Spread          0.000000e+00
# ML             -4.368981e+01
# PTS             1.120912e+02
# PLUS_MINUS      4.629630e-04
# WIN             5.000000e-01
# LOSS            5.000000e-01
# WINS_SEASON     1.797418e+01
# LOSS_SEASON     1.802582e+01
# WIN_%                    inf
# back_to_back    2.115741e-01
# FG_PCT          4.669144e-01
# FG3_PCT         3.653912e-01
# FT_PCT          7.785556e-01
# EFG_PCT_y       5.390167e-01
# FTA_RATE        2.495380e-01
# TM_TOV_PCT_y    1.353514e-01
# OREB_PCT_y      1.964630e-01
# OPP_EFG_PCT     5.390167e-01
# OPP_FTA_RATE    2.495380e-01
# OPP_TOV_PCT     1.353514e-01
# OPP_OREB_PCT    2.625296e-01
# PIE             5.000037e-01
# OFF_RATING      1.117391e+02
# DEF_RATING      1.117391e+02
# NET_RATING      0.000000e+00
# TS_PCT          5.728940e-01
# PACE            9.975464e+01
# AST_TOV         1.975444e+00
# HOME_TEAM       5.000000e-01
# PTS_ALLOWED     1.120907e+02
# dtype: float64

# %%
just_game = ['TEAM_ID',
 'Team',
 'GAME_ID',
 'GAME_DATE',
 'MATCHUP',
 'Over/Under',
 'Spread',
 'ML',
 'WL',
 'Spread_Result',
 'PTS',
 'PLUS_MINUS',
 'WIN',
 'LOSS',
 'WINS_SEASON',
 'LOSS_SEASON',
 'WIN_%',
 'previous_day',
 'back_to_back',
 'FG_PCT',
 'FG3_PCT',
 'FT_PCT',
 'EFG_PCT_y',
 'FTA_RATE',
 'TM_TOV_PCT_y',
 'OREB_PCT_y',
 'OPP_EFG_PCT',
 'OPP_FTA_RATE',
 'OPP_TOV_PCT',
 'OPP_OREB_PCT',
 'PIE',
 'OFF_RATING',
 'DEF_RATING',
 'NET_RATING',
 'TS_PCT',
 'PACE',
 'AST_TOV',
 'HOME_TEAM',
 'PTS_ALLOWED']

# %%
b2bs[just_game]['WIN'].sum()
# Out:
# 216

# %%
rest['WIN'].sum()
# Out:
# 864

# %%
len(rest)
# Out:
# 1703

# %%
864/1703
# Out:
# 0.5073399882560188

# %%
len(b2bs)
# Out:
# 457

# %%
216/457
# Out:
# 0.4726477024070022

# %%
b2bs['PTS'].mean()
# Out:
# 111.28227571115974

# %%
b2bs['PTS_ALLOWED'].mean()
# Out:
# 112.05864332603939

# %%
b2bs['EFG_PCT_y'].mean()
# Out:
# 0.536070021881838

# %%
model_df21['PTS'].mean()
# Out:
# 112.0912037037037

# %%
rest['PTS_ALLOWED'].mean()
# Out:
# 112.09935408103348

# %%
model_df21['EFG_PCT_y'].mean()
# Out:
# 0.5390166666666667

# %%
plt.figure(figsize=(15, 9))

ax1 = plt.subplot2grid(shape=(2,4), loc=(0,0))
ax1.set(ylim= (.40, .60))
ax1.set_title('Win %')
ax2 = plt.subplot2grid(shape=(2,4), loc=(0,1))
ax2.set(ylim= (100, 120))
ax2.set_title('PPG')
ax3 = plt.subplot2grid(shape=(2,4), loc=(1,0))
ax3.set(ylim= (.7, .8))
ax3.set_title('FT %')
ax4 = plt.subplot2grid(shape=(2,4), loc=(1,1))
ax4.set(ylim= (.4,.5))
ax4.set_title('FG %')

sns.barplot(x = ['Home', 'Away'], y = [(home['WIN'].sum()/len(home)), (away['WIN'].sum()/len(away))], ax = ax1)
sns.barplot(x = ['Home', 'Away'], y = [home['PTS'].mean(), away['PTS'].mean()], ax=ax2)
sns.barplot(x = ['Home', 'Away'], y = [home['FT_PCT'].mean(), away['FT_PCT'].mean()], ax=ax3)
sns.barplot(x = ['Home', 'Away'], y = [home['FG_PCT'].mean(), away['FG_PCT'].mean()], ax=ax4)
# Out:
# <AxesSubplot:title={'center':'FG %'}>

# %%
plt.figure(figsize=(15, 9))

ax1 = plt.subplot2grid(shape=(2,4), loc=(0,0))
ax1.set(ylim= (.45,.55))
ax1.set_title('Win %')
ax2 = plt.subplot2grid(shape=(2,4), loc=(0,1))
ax2.set(ylim= (100, 120))
ax2.set_title('PPG')
ax3 = plt.subplot2grid(shape=(2,4), loc=(1,0))
ax3.set(ylim= (.7, .8))
ax3.set_title('FT %')
ax4 = plt.subplot2grid(shape=(2,4), loc=(1,1))
ax4.set(ylim= (.4,.5))
ax4.set_title('FG %')

sns.barplot(x = ['Back to Back', 'Rested'], y = [0.4726477024070022, .5073399882560188], ax = ax1)
sns.barplot(x = ['Back to Back', 'Rested'], y = [b2bs['PTS'].mean(), rest['PTS'].mean()], ax=ax2)
sns.barplot(x = ['Back to Back', 'Rested'], y = [b2bs['FT_PCT'].mean(), rest['FT_PCT'].mean()], ax=ax3)
sns.barplot(x = ['Back to Back', 'Rested'], y = [b2bs['FG_PCT'].mean(), rest['FG_PCT'].mean()], ax=ax4)
;
# Out:
# ''

# %%
from nba_api.stats.endpoints import leaguedashteamstats

# %%
league = leaguedashteamstats.LeagueDashTeamStats(measure_type_detailed_defense='Advanced', season='2020-21')
league = league.get_data_frames()[0]

# %%
league.columns
# Out:
# Index(['TEAM_ID', 'TEAM_NAME', 'GP', 'W', 'L', 'W_PCT', 'MIN', 'E_OFF_RATING',
#        'OFF_RATING', 'E_DEF_RATING', 'DEF_RATING', 'E_NET_RATING',
#        'NET_RATING', 'AST_PCT', 'AST_TO', 'AST_RATIO', 'OREB_PCT', 'DREB_PCT',
#        'REB_PCT', 'TM_TOV_PCT', 'EFG_PCT', 'TS_PCT', 'E_PACE', 'PACE',
#        'PACE_PER40', 'POSS', 'PIE', 'GP_RANK', 'W_RANK', 'L_RANK',
#        'W_PCT_RANK', 'MIN_RANK', 'OFF_RATING_RANK', 'DEF_RATING_RANK',
#        'NET_RATING_RANK', 'AST_PCT_RANK', 'AST_TO_RANK', 'AST_RATIO_RANK',
#        'OREB_PCT_RANK', 'DREB_PCT_RANK', 'REB_PCT_RANK', 'TM_TOV_PCT_RANK',
#        'EFG_PCT_RANK', 'TS_PCT_RANK', 'PACE_RANK', 'PIE_RANK', 'CFID',
#        'CFPARAMS'],
#       dtype='object')

# %%
league = league[['TEAM_ID', 'TEAM_NAME', 'GP', 'W', 'L', 'W_PCT', 'OFF_RATING_RANK', 'DEF_RATING_RANK', 'NET_RATING_RANK',
       'AST_PCT_RANK', 'AST_TO_RANK', 'AST_RATIO_RANK',
       'OREB_PCT_RANK', 'DREB_PCT_RANK', 'REB_PCT_RANK', 'TM_TOV_PCT_RANK',
       'EFG_PCT_RANK', 'TS_PCT_RANK', 'PACE_RANK', 'PIE_RANK']]

# %%
league.corr()['W_PCT']
# Out:
# TEAM_ID           -0.071579
# GP                      NaN
# W                  0.999997
# L                 -0.999997
# W_PCT              1.000000
# OFF_RATING_RANK   -0.795313
# DEF_RATING_RANK   -0.654128
# NET_RATING_RANK   -0.949628
# AST_PCT_RANK       0.157231
# AST_TO_RANK       -0.453183
# AST_RATIO_RANK    -0.302559
# OREB_PCT_RANK     -0.185181
# DREB_PCT_RANK     -0.410413
# REB_PCT_RANK      -0.594256
# TM_TOV_PCT_RANK   -0.306644
# EFG_PCT_RANK      -0.790270
# TS_PCT_RANK       -0.846930
# PACE_RANK          0.266184
# PIE_RANK          -0.936668
# Name: W_PCT, dtype: float64

# %%
league.sort_values(by = ['W_PCT'])
# Out:
#        TEAM_ID               TEAM_NAME  GP   W   L  W_PCT  OFF_RATING_RANK  \
# 10  1610612745         Houston Rockets  72  17  55  0.236               27
# 8   1610612765         Detroit Pistons  72  20  52  0.278               26
# 21  1610612753           Orlando Magic  72  21  51  0.292               29
# 5   1610612739     Cleveland Cavaliers  72  22  50  0.306               28
# 20  1610612760   Oklahoma City Thunder  72  22  50  0.306               30
# 17  1610612750  Minnesota Timberwolves  72  23  49  0.319               25
# 27  1610612761         Toronto Raptors  72  27  45  0.375               16
# 4   1610612741           Chicago Bulls  72  31  41  0.431               21
# 25  1610612758        Sacramento Kings  72  31  41  0.431               12
# 18  1610612740    New Orleans Pelicans  72  31  41  0.431               11
# 3   1610612766       Charlotte Hornets  72  33  39  0.458               23
# 26  1610612759       San Antonio Spurs  72  33  39  0.458               19
# 29  1610612764      Washington Wizards  72  34  38  0.472               17
# 11  1610612754          Indiana Pacers  72  34  38  0.472               14
# 1   1610612738          Boston Celtics  72  36  36  0.500               10
# 14  1610612763       Memphis Grizzlies  72  38  34  0.528               15
# 9   1610612744   Golden State Warriors  72  39  33  0.542               20
# 15  1610612748              Miami Heat  72  40  32  0.556               18
# 19  1610612752         New York Knicks  72  41  31  0.569               22
# 0   1610612737           Atlanta Hawks  72  41  31  0.569                9
# 13  1610612747      Los Angeles Lakers  72  42  30  0.583               24
# 24  1610612757  Portland Trail Blazers  72  42  30  0.583                2
# 6   1610612742        Dallas Mavericks  72  42  30  0.583                8
# 16  1610612749         Milwaukee Bucks  72  46  26  0.639                5
# 12  1610612746             LA Clippers  72  47  25  0.653                3
# 7   1610612743          Denver Nuggets  72  47  25  0.653                6
# 2   1610612751           Brooklyn Nets  72  48  24  0.667                1
# 22  1610612755      Philadelphia 76ers  72  49  23  0.681               13
# 23  1610612756            Phoenix Suns  72  51  21  0.708                7
# 28  1610612762               Utah Jazz  72  52  20  0.722                4
#
#     DEF_RATING_RANK  NET_RATING_RANK  AST_PCT_RANK  AST_TO_RANK  \
# 10               27               27            16           28
# 8                19               25             8           26
# 21               26               29            24           21
# 5                25               28            12           29
# 20               24               30            26           30
# 17               28               26             6           17
# 27               15               19            14           15
# 4                12               20             4           20
# 25               30               24            17            8
# 18               23               18            13           18
# 3                16               23             1           16
# 26               17               21            20            2
# 29               20               22            19           19
# 11               14               16             5            4
# 1                13               13            27           22
# 14                7               14             7            3
# 9                 5               15             3           12
# 15               10               17             2           10
# 19                4                9            29           24
# 0                18               11            18           14
# 13                1                8            15           27
# 24               29               12            30            7
# 6                21               10            28            9
# 16                9                4            25           13
# 12                8                2            21           11
# 7                11                6            11            5
# 2                22                7            10            6
# 22                2                5            23           25
# 23                6                3             9            1
# 28                3                1            22           23
#
#     AST_RATIO_RANK  OREB_PCT_RANK  DREB_PCT_RANK  REB_PCT_RANK  \
# 10              25             28             25            30
# 8               18             15             24            21
# 21              28             23              8            23
# 5               21              7             21            15
# 20              29             19             10            20
# 17              14             11             27            25
# 27              19             18             28            28
# 4                8             16              1             4
# 25              10             20             29            26
# 18              11              1              3             2
# 3                7              9             26            17
# 26              16             27             18            24
# 29              17             24             16            19
# 11               6             26             30            29
# 1               26              3             13            10
# 14               9              4             15            11
# 9                2             30             22            27
# 15               3             29             19            22
# 19              27             17             12            12
# 0               20              6              9             7
# 13              15             14              7             9
# 24              30             10             20            18
# 6               23             21             17            16
# 16              13             13              4             5
# 12              12             12              5             6
# 7                4              2              6             3
# 2                5             22             23            13
# 22              24              8             14             8
# 23               1             25             11            14
# 28              22              5              2             1
#
#     TM_TOV_PCT_RANK  EFG_PCT_RANK  TS_PCT_RANK  PACE_RANK  PIE_RANK
# 10               23            24           27          6        28
# 8                26            26           24         23        25
# 21                5            30           30         17        29
# 5                29            29           28         25        27
# 20               30            28           29          7        30
# 17               17            25           25          5        26
# 27                9            21           20         14        23
# 4                27            10           14         13        18
# 25                8             9           12          9        24
# 18               22            17           17         10        14
# 3                25            19           21         18        22
# 26                2            27           26         15        21
# 29               16            20           18          1        19
# 11                7            13           15          4        16
# 1                18            12           16         20        17
# 14                6            22           22          8         9
# 9                24             7            7          3        12
# 15               21            11            9         29        13
# 19               11            23           23         30        15
# 0                10            16           10         22        10
# 13               28            18           19         21         8
# 24                1            15           13         19        20
# 6                 3             8            8         26        11
# 16               13             2            5          2         4
# 12               14             4            2         28         6
# 7                15             6            6         27         7
# 2                12             1            1         11         5
# 22               20            14           11         12         2
# 23                4             3            3         24         3
# 28               19             5            4         16         1
