# %%
import pickle
import pandas as pd
import numpy as np

# %%
from nba_api.stats.endpoints import leaguedashplayerstats

players21 = leaguedashplayerstats.LeagueDashPlayerStats(season='2020-21', measure_type_detailed_defense='Advanced')
playerstats21 = players21.get_data_frames()[0]
players20 = leaguedashplayerstats.LeagueDashPlayerStats(season='2019-20', measure_type_detailed_defense='Advanced')
playerstats20 = players20.get_data_frames()[0]
players19 = leaguedashplayerstats.LeagueDashPlayerStats(season='2018-19', measure_type_detailed_defense='Advanced')
playerstats19 = players19.get_data_frames()[0]
players18 = leaguedashplayerstats.LeagueDashPlayerStats(season='2017-18', measure_type_detailed_defense='Advanced')
playerstats18 = players18.get_data_frames()[0]
players17 = leaguedashplayerstats.LeagueDashPlayerStats(season='2016-17', measure_type_detailed_defense='Advanced')
playerstats17 = players17.get_data_frames()[0]
players16 = leaguedashplayerstats.LeagueDashPlayerStats(season='2015-16', measure_type_detailed_defense='Advanced')
playerstats16 = players16.get_data_frames()[0]

# %%
playerstats21[['PLAYER_ID', 'PLAYER_NAME', 'TEAM_ID', 'NET_RATING']]
# Out:
#      PLAYER_ID      PLAYER_NAME     TEAM_ID  NET_RATING
# 0       203932     Aaron Gordon  1610612743         2.1
# 1      1628988    Aaron Holiday  1610612754        -0.2
# 2      1630174    Aaron Nesmith  1610612738        -0.5
# 3      1627846      Abdel Nader  1610612756         5.0
# 4      1629690      Adam Mokoka  1610612741        -7.1
# ..         ...              ...         ...         ...
# 535    1627812     Yogi Ferrell  1610612746        -0.4
# 536    1629139    Yuta Watanabe  1610612761        -2.7
# 537     203897      Zach LaVine  1610612741        -0.8
# 538    1630192       Zeke Nnaji  1610612743       -10.5
# 539    1629627  Zion Williamson  1610612740         2.1
#
# [540 rows x 4 columns]

# %%
playerdict20 = dict(zip(playerstats20.PLAYER_ID, playerstats20.NET_RATING))
playerdict19 = dict(zip(playerstats19.PLAYER_ID, playerstats19.NET_RATING))
playerdict18 = dict(zip(playerstats18.PLAYER_ID, playerstats18.NET_RATING))
playerdict17 = dict(zip(playerstats17.PLAYER_ID, playerstats17.NET_RATING))
playerdict16 = dict(zip(playerstats16.PLAYER_ID, playerstats16.NET_RATING))

# %%
players15= leaguedashplayerstats.LeagueDashPlayerStats(season='2014-15', measure_type_detailed_defense='Advanced')
playerstats15 = players15.get_data_frames()[0]
playerdict15 = dict(zip(playerstats15.PLAYER_ID, playerstats15.NET_RATING))

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2

pbs = boxscoreadvancedv2.BoxScoreAdvancedV2('0022000002')
pbs = pbs.get_data_frames()[0]

pbs = pbs.loc[pbs['START_POSITION'].isin(['F', 'C', 'G'])]
for ind in pbs.index:
    player_id = pbs.PLAYER_ID[ind]
    pbs['2020_NR'] = pbs.PLAYER_ID.map(playerdict20)
    pbs['2019_NR'] = pbs.PLAYER_ID.map(playerdict19)
pbs
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0   0022000002  1610612746               LAC           LA     202695
# 1   0022000002  1610612746               LAC           LA     201587
# 2   0022000002  1610612746               LAC           LA     201586
# 3   0022000002  1610612746               LAC           LA     202331
# 4   0022000002  1610612746               LAC           LA     201976
# 14  0022000002  1610612747               LAL  Los Angeles       2544
# 15  0022000002  1610612747               LAL  Los Angeles     203076
# 16  0022000002  1610612747               LAL  Los Angeles     201188
# 17  0022000002  1610612747               LAL  Los Angeles     203484
# 18  0022000002  1610612747               LAL  Los Angeles     203471
#
#                  PLAYER_NAME    NICKNAME START_POSITION COMMENT    MIN  ...  \
# 0              Kawhi Leonard       Kawhi              F          34:00  ...
# ...

# %%
pbs2 = boxscoreadvancedv2.BoxScoreAdvancedV2('0022000002')
pbs2 = pbs.get_data_frames()[0]

pbs2 = pbs.loc[pbs['START_POSITION'].isin(['F', 'C', 'G'])]
for ind in pbs2.index:
    player_id = pbs.PLAYER_ID[ind]
    pbs2['2020_NR'] = pbs.PLAYER_ID.map(playerdict20)
    pbs2['2019_NR'] = pbs.PLAYER_ID.map(playerdict19)
pbs2

# %%
game_id_list
# Out:
# {'0022000002': {1610612747: 5.5, 1610612746: 10.2},
#  '0022000001': {},
#  '0022000014': {}}

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2

pbs = boxscoreadvancedv2.BoxScoreAdvancedV2('0022000001')
pbs = pbs.get_data_frames()[0]

pbs = pbs.loc[pbs['START_POSITION'].isin(['F', 'C', 'G'])]

# %%
for ind in pbs.index:
    player_id = pbs.PLAYER_ID[ind]
    pbs['2020_NR'] = pbs.PLAYER_ID.map(playerdict20)
    pbs['2019_NR'] = pbs.PLAYER_ID.map(playerdict19)

# %%
pbs
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0022000001  1610612744               GSW  Golden State     203952
# 1   0022000001  1610612744               GSW  Golden State    1629672
# 2   0022000001  1610612744               GSW  Golden State    1630164
# 3   0022000001  1610612744               GSW  Golden State    1626162
# 4   0022000001  1610612744               GSW  Golden State     201939
# 13  0022000001  1610612751               BKN      Brooklyn     203925
# 14  0022000001  1610612751               BKN      Brooklyn     201142
# 15  0022000001  1610612751               BKN      Brooklyn     201599
# 16  0022000001  1610612751               BKN      Brooklyn     203915
# 17  0022000001  1610612751               BKN      Brooklyn     202681
#
#           PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  TS_PCT  \
# 0      Andrew Wiggins   Andrew              F          31:14  ...   0.366
# ...

# %%
for team in pbs.groupby('TEAM_ID').groups:
    print(team)
# Out:
# 1610612746
# 1610612747

# %%
pbs
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION  TEAM_CITY  PLAYER_ID  \
# 0   0021601218  1610612761               TOR    Toronto     201960
# 1   0021601218  1610612761               TOR    Toronto     202335
# 2   0021601218  1610612761               TOR    Toronto     202685
# 3   0021601218  1610612761               TOR    Toronto    1626181
# 4   0021601218  1610612761               TOR    Toronto     200768
# 13  0021601218  1610612739               CLE  Cleveland       2747
# 14  0021601218  1610612739               CLE  Cleveland     202684
# 15  0021601218  1610612739               CLE  Cleveland     101112
# 16  0021601218  1610612739               CLE  Cleveland     202697
# 17  0021601218  1610612739               CLE  Cleveland     101114
#
#           PLAYER_NAME  NICKNAME START_POSITION COMMENT    MIN  E_OFF_RATING  \
# 0     DeMarre Carroll   DeMarre              F          16:28         102.0
# ...

# %%
game_id_dict_21 = {}
for n in range(0, len(df21)):
    pbs = boxscoreadvancedv2.BoxScoreAdvancedV2(df21.GAME_ID[n])
    pbs = pbs.get_data_frames()[0]
    pbs = pbs.loc[pbs['START_POSITION'].isin(['F', 'C', 'G'])]
    game_id_list[df21.GAME_ID[n]] = []
    for ind in pbs.index:
        player_id = pbs.PLAYER_ID[ind]
        pbs['2020_NR'] = pbs.PLAYER_ID.map(playerdict20)
        pbs['2019_NR'] = pbs.PLAYER_ID.map(playerdict19)
    pbs = pbs.fillna(0)
    team_nr = {}
    for team in pbs.groupby('TEAM_ID').groups:  
        comb_nr = 0
        team_nr[team] = []
        for ind in pbs.loc[pbs['TEAM_ID'] == team].index:           
            if pbs['2020_NR'][ind] > pbs['2019_NR'][ind]:
                player_nr = pbs['2020_NR'][ind]
                comb_nr = (comb_nr + player_nr)
            else:
                player_nr = pbs['2019_NR'][ind]
                comb_nr = (comb_nr + player_nr)
            team_nr[pbs.TEAM_ID[ind]] = comb_nr
    game_id_dict_21[df21.GAME_ID[n]] = team_nr

# %%
len(game_id_dict_21)
# Out:
# 1080

# %%
len(game_id_dict_19)
# Out:
# 1230

# %%
game_id_dict_20 = {}
for n in range(0, len(df20)):
    pbs = boxscoreadvancedv2.BoxScoreAdvancedV2(df20.GAME_ID[n])
    pbs = pbs.get_data_frames()[0]
    pbs = pbs.loc[pbs['START_POSITION'].isin(['F', 'C', 'G'])]
    game_id_list[df20.GAME_ID[n]] = []
    for ind in pbs.index:
        player_id = pbs.PLAYER_ID[ind]
        pbs['2019_NR'] = pbs.PLAYER_ID.map(playerdict19)
        pbs['2018_NR'] = pbs.PLAYER_ID.map(playerdict18)
    pbs = pbs.fillna(0)
    team_nr = {}
    for team in pbs.groupby('TEAM_ID').groups:  
        comb_nr = 0
        team_nr[team] = []
        for ind in pbs.loc[pbs['TEAM_ID'] == team].index:           
            if pbs['2019_NR'][ind] > pbs['2018_NR'][ind]:
                player_nr = pbs['2019_NR'][ind]
                comb_nr = (comb_nr + player_nr)
            else:
                player_nr = pbs['2018_NR'][ind]
                comb_nr = (comb_nr + player_nr)
            team_nr[pbs.TEAM_ID[ind]] = comb_nr
    game_id_dict_20[df20.GAME_ID[n]] = team_nr

# %%
game_id_dict_19 = {}
for n in range(0, len(df19)):
    pbs = boxscoreadvancedv2.BoxScoreAdvancedV2(df19.GAME_ID[n])
    pbs = pbs.get_data_frames()[0]
    pbs = pbs.loc[pbs['START_POSITION'].isin(['F', 'C', 'G'])]
    game_id_list[df19.GAME_ID[n]] = []
    for ind in pbs.index:
        player_id = pbs.PLAYER_ID[ind]
        pbs['2018_NR'] = pbs.PLAYER_ID.map(playerdict18)
        pbs['2017_NR'] = pbs.PLAYER_ID.map(playerdict17)
    pbs = pbs.fillna(0)
    team_nr = {}
    for team in pbs.groupby('TEAM_ID').groups:  
        comb_nr = 0
        team_nr[team] = []
        for ind in pbs.loc[pbs['TEAM_ID'] == team].index:           
            if pbs['2018_NR'][ind] > pbs['2017_NR'][ind]:
                player_nr = pbs['2018_NR'][ind]
                comb_nr = (comb_nr + player_nr)
            else:
                player_nr = pbs['2017_NR'][ind]
                comb_nr = (comb_nr + player_nr)
            team_nr[pbs.TEAM_ID[ind]] = comb_nr
    game_id_dict_19[df19.GAME_ID[n]] = team_nr

# %%
game_id_dict_18 = {}
for n in range(0, len(df18)):
    pbs = boxscoreadvancedv2.BoxScoreAdvancedV2(df18.GAME_ID[n])
    pbs = pbs.get_data_frames()[0]
    pbs = pbs.loc[pbs['START_POSITION'].isin(['F', 'C', 'G'])]
    game_id_list[df18.GAME_ID[n]] = []
    for ind in pbs.index:
        player_id = pbs.PLAYER_ID[ind]
        pbs['2017_NR'] = pbs.PLAYER_ID.map(playerdict17)
        pbs['2016_NR'] = pbs.PLAYER_ID.map(playerdict16)
    pbs = pbs.fillna(0)
    team_nr = {}
    for team in pbs.groupby('TEAM_ID').groups:  
        comb_nr = 0
        team_nr[team] = []
        for ind in pbs.loc[pbs['TEAM_ID'] == team].index:           
            if pbs['2017_NR'][ind] > pbs['2016_NR'][ind]:
                player_nr = pbs['2017_NR'][ind]
                comb_nr = (comb_nr + player_nr)
            else:
                player_nr = pbs['2016_NR'][ind]
                comb_nr = (comb_nr + player_nr)
            team_nr[pbs.TEAM_ID[ind]] = comb_nr
    game_id_dict_18[df18.GAME_ID[n]] = team_nr

# %%
game_id_dict_17 = {}
for n in range(0, len(df17)):
    pbs = boxscoreadvancedv2.BoxScoreAdvancedV2(df17.GAME_ID[n])
    pbs = pbs.get_data_frames()[0]
    pbs = pbs.loc[pbs['START_POSITION'].isin(['F', 'C', 'G'])]
    game_id_list[df17.GAME_ID[n]] = []
    for ind in pbs.index:
        player_id = pbs.PLAYER_ID[ind]
        pbs['2016_NR'] = pbs.PLAYER_ID.map(playerdict16)
        pbs['2015_NR'] = pbs.PLAYER_ID.map(playerdict15)
    pbs = pbs.fillna(0)
    team_nr = {}
    for team in pbs.groupby('TEAM_ID').groups:  
        comb_nr = 0
        team_nr[team] = []
        for ind in pbs.loc[pbs['TEAM_ID'] == team].index:           
            if pbs['2016_NR'][ind] > pbs['2015_NR'][ind]:
                player_nr = pbs['2016_NR'][ind]
                comb_nr = (comb_nr + player_nr)
            else:
                player_nr = pbs['2015_NR'][ind]
                comb_nr = (comb_nr + player_nr)
            team_nr[pbs.TEAM_ID[ind]] = comb_nr
    game_id_dict_17[df17.GAME_ID[n]] = team_nr

# %%
with open('data/pickles/net_rating21.p', 'wb') as writefile: 
    pickle.dump(game_id_dict_21, writefile)
with open('data/pickles/net_rating20.p', 'wb') as writefile: 
    pickle.dump(game_id_dict_20, writefile)
with open('data/pickles/net_rating19.p', 'wb') as writefile: 
    pickle.dump(game_id_dict_19, writefile)
with open('data/pickles/net_rating18.p', 'wb') as writefile: 
    pickle.dump(game_id_dict_18, writefile)
with open('data/pickles/net_rating17.p', 'wb') as writefile: 
    pickle.dump(game_id_dict_17, writefile)

# %%
pbs = pbs.fillna(0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-f84b13d296f6> in <module>
# ----> 1 pbs = pbs.fillna(0)
#
# NameError: name 'pbs' is not defined

# %%
team_nr = {}
for team in pbs.groupby('TEAM_ID').groups:
    comb_nr = 0
    print(comb_nr)
    team_nr[team] = []
    for ind in pbs.loc[pbs['TEAM_ID'] == team].index:
        if pbs['2020_NR'][ind] > pbs['2019_NR'][ind]:
            player_nr = pbs['2020_NR'][ind]
            comb_nr = (comb_nr + player_nr)
        else:
            player_nr = pbs['2019_NR'][ind]
            comb_nr = (comb_nr + player_nr)
    team_nr[team] = comb_nr
# Out:
# 0
# 0

# %%
pd.set_option('display.max_columns', None)

# %%
with open('data/pickles/testdf21.p', 'rb') as readfile: 
     testdf21 = pickle.load(readfile)

with open('data/pickles/testdf20.p', 'rb') as readfile: 
     testdf20 = pickle.load(readfile)
        
with open('data/pickles/testdf19.p', 'rb') as readfile: 
     testdf19 = pickle.load(readfile)
        
with open('data/pickles/testdf18.p', 'rb') as readfile: 
     testdf18 = pickle.load(readfile)
        
with open('data/pickles/testdf17.p', 'rb') as readfile: 
     testdf17 = pickle.load(readfile)

# %%
with open('data/pickles/starters20.p', 'rb') as readfile: 
    starters20 = pickle.load(readfile)

# %%
starters20
# Out:
#       index     GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0         0  0021900001  1610612740               NOP  New Orleans     201950
# 1         1  0021900001  1610612740               NOP  New Orleans    1627742
# 2         2  0021900001  1610612740               NOP  New Orleans     202324
# 3         3  0021900001  1610612740               NOP  New Orleans     200755
# 4         4  0021900001  1610612740               NOP  New Orleans    1628366
# ...     ...         ...         ...               ...          ...        ...
# 5925     13  0021900593  1610612738               BOS       Boston     202330
# 5926     14  0021900593  1610612738               BOS       Boston    1628369
# 5927     15  0021900593  1610612738               BOS       Boston     202683
# 5928     16  0021900593  1610612738               BOS       Boston    1627759
# 5929     17  0021900593  1610612738               BOS       Boston     202689
#
# ...

# %%
testdf20[590:600]
# Out:
#       TEAM_ID_Home               Team_Home     GAME_ID   GAME_DATE  \
# 2362    1610612765         Detroit Pistons  0021900591  2020-01-13
# 2366    1610612754          Indiana Pacers  0021900592  2020-01-13
# 2370    1610612738          Boston Celtics  0021900593  2020-01-13
# 2373    1610612750  Minnesota Timberwolves  0021900594  2020-01-13
# 2377    1610612757  Portland Trail Blazers  0021900595  2020-01-13
# 2381    1610612758        Sacramento Kings  0021900596  2020-01-13
# 2386    1610612747      Los Angeles Lakers  0021900597  2020-01-13
# 2389    1610612737           Atlanta Hawks  0021900598  2020-01-14
# 2393    1610612751           Brooklyn Nets  0021900599  2020-01-14
# 2398    1610612763       Memphis Grizzlies  0021900600  2020-01-14
#
#      MATCHUP_Home  Over/Under  Spread_Home  ML_Home WL_Home  \
# 2362  DET vs. NOP       221.5         -5.0     -108       L
# 2366  IND vs. PHI       214.5         -3.5     -130       W
# ...

# %%
testdf21.reset_index(inplace=True)

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2

bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = '0022000001')
bsa = bsa.get_data_frames()[0]

starters21 = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]

# %%
for n in range(1, (len(testdf21))):
    bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf21['GAME_ID'][n])
    bsa = bsa.get_data_frames()[0]
    bsa = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]
    starters21 = starters21.append(bsa)

# %%
testdf20.reset_index(inplace=True)

# %%
from nba_api.stats.endpoints import boxscoreadvancedv2
# bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf20['GAME_ID'][0])
# bsa = bsa.get_data_frames()[0]
# starters20 = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]

# %%
testdf20['GAME_ID'][593]
# Out:
# '0021900594'

# %%
for n in range(593, (len(testdf20) - 593)):
    bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf20['GAME_ID'][n])
    bsa = bsa.get_data_frames()[0]
    bsa = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]
    starters20 = starters20.append(bsa)

# %%
bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf20['GAME_ID'][0])
bsa = bsa.get_data_frames()[0]
starters20fix = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]

for n in range(1, (len(testdf20))):
    bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf20['GAME_ID'][n])
    bsa = bsa.get_data_frames()[0]
    bsa = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]
    starters20fix = starters20fix.append(bsa)

# %%
starters20fix
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION    TEAM_CITY  PLAYER_ID  \
# 0   0021900001  1610612740               NOP  New Orleans     201950
# 1   0021900001  1610612740               NOP  New Orleans    1627742
# 2   0021900001  1610612740               NOP  New Orleans     202324
# 3   0021900001  1610612740               NOP  New Orleans     200755
# 4   0021900001  1610612740               NOP  New Orleans    1628366
# ..         ...         ...               ...          ...        ...
# 13  0021901318  1610612761               TOR      Toronto    1626181
# 14  0021901318  1610612761               TOR      Toronto    1626178
# 15  0021901318  1610612761               TOR      Toronto     201188
# 16  0021901318  1610612761               TOR      Toronto    1629744
# 17  0021901318  1610612761               TOR      Toronto    1629056
#
#                 PLAYER_NAME NICKNAME START_POSITION COMMENT    MIN  ...  \
# ...

# %%
with open('data/pickles/starters20a.p', 'wb') as writefile: 
    pickle.dump(starters20fix, writefile)

# %%
testdf19.reset_index(inplace=True)
bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf19['GAME_ID'][0])
bsa = bsa.get_data_frames()[0]
starters19 = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]

for n in range(1, (len(testdf19))):
    bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf19['GAME_ID'][n])
    bsa = bsa.get_data_frames()[0]
    bsa = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]
    starters19 = starters19.append(bsa)

# %%
testdf18.reset_index(inplace=True)
bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf18['GAME_ID'][0])
bsa = bsa.get_data_frames()[0]
starters18 = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]

for n in range(1, (len(testdf18))):
    bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf18['GAME_ID'][n])
    bsa = bsa.get_data_frames()[0]
    bsa = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]
    starters18 = starters18.append(bsa)

# %%
testdf17.reset_index(inplace=True)
bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf17['GAME_ID'][0])
bsa = bsa.get_data_frames()[0]
starters17 = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]

for n in range(1, (len(testdf17))):
    bsa = boxscoreadvancedv2.BoxScoreAdvancedV2(game_id = testdf17['GAME_ID'][n])
    bsa = bsa.get_data_frames()[0]
    bsa = bsa.loc[bsa['START_POSITION'].isin(['F', 'C', 'G'])]
    starters17 = starters17.append(bsa)

# %%
list(starters17.columns)
# Out:
# ['GAME_ID',
#  'TEAM_ID',
#  'TEAM_ABBREVIATION',
#  'TEAM_CITY',
#  'PLAYER_ID',
#  'PLAYER_NAME',
#  'NICKNAME',
#  'START_POSITION',
#  'COMMENT',
#  'MIN',
#  'E_OFF_RATING',
#  'OFF_RATING',
#  'E_DEF_RATING',
#  'DEF_RATING',
#  'E_NET_RATING',
#  'NET_RATING',
#  'AST_PCT',
#  'AST_TOV',
#  'AST_RATIO',
#  'OREB_PCT',
#  'DREB_PCT',
#  'REB_PCT',
#  'TM_TOV_PCT',
#  'EFG_PCT',
#  'TS_PCT',
#  'USG_PCT',
#  'E_USG_PCT',
#  'E_PACE',
#  'PACE',
#  'PACE_PER40',
#  'POSS',
#  'PIE']

# %%
rol_col_ind = ['OFF_RATING', 'DEF_RATING', 'NET_RATING', 'EFG_PCT',
 'TS_PCT', 'PACE', 'PIE']

# %%
def merge_expanding_means_ind(df):
    exp_lists = {}
    exp_ind = {}
    for column in rol_col_ind:
        exp_lists[column] = []
        exp_ind[column] = []

    exp_series_dict = {}
    for column in rol_col_ind:
        exp_series_dict[f'Season{column}'] = []
        
    for column in rol_col_ind:
    
        for team in df.groupby('PLAYER_ID').groups:
            team_rol = df.groupby('PLAYER_ID')[column].expanding().mean()[team].shift()
            exp_lists[column].extend(list(team_rol.values))
            exp_ind[column].extend(list(team_rol.index))
    
        exp_series_dict[f'Season{column}'] = pd.Series(exp_lists[column], exp_ind[column], name = f"{column} Season")
    
    for series in exp_series_dict:
        df = df.merge(exp_series_dict[series], left_index=True, right_index=True)
        
    return df

# %%
merge_expanding_means_ind(starters17)

# %%
starters

# %%
merge_expanding_means_ind(starters21)
merge_expanding_means_ind(starters20)
merge_expanding_means_ind(starters19)

# %%
with open('data/pickles/starters21.p', 'wb') as writefile: 
    pickle.dump(starters21, writefile)
with open('data/pickles/starters20.p', 'wb') as writefile: 
    pickle.dump(starters20, writefile)
with open('data/pickles/starters19.p', 'wb') as writefile: 
    pickle.dump(starters19, writefile)
with open('data/pickles/starters18.p', 'wb') as writefile: 
    pickle.dump(starters18, writefile)
with open('data/pickles/starters17.p', 'wb') as writefile: 
    pickle.dump(starters17, writefile)

# %%
with open('data/pickles/model_df21.p', 'rb') as readfile: 
    model_df21 = pickle.load(readfile)
    
with open('data/pickles/model_df20.p', 'rb') as readfile: 
    model_df20 = pickle.load(readfile)
    
with open('data/pickles/model_df19.p', 'rb') as readfile: 
    model_df19 = pickle.load(readfile)
    
with open('data/pickles/model_df18.p', 'rb') as readfile: 
    model_df18 = pickle.load(readfile)
    
with open('data/pickles/model_df17.p', 'rb') as readfile: 
    model_df17 = pickle.load(readfile)

# %%
with open('data/pickles/df21.p', 'rb') as readfile: 
     df21 = pickle.load(readfile)
        
with open('data/pickles/df20.p', 'rb') as readfile: 
     df20 = pickle.load(readfile)
        
with open('data/pickles/df19.p', 'rb') as readfile: 
     df19 = pickle.load(readfile)
        
with open('data/pickles/df18.p', 'rb') as readfile: 
     df18 = pickle.load(readfile)
        
with open('data/pickles/df17.p', 'rb') as readfile: 
     df17 = pickle.load(readfile)
